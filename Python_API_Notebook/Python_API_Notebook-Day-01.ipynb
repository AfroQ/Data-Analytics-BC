# %% [markdown]
# # Day 01
# # Instructor Turn - 01- Requests Demo  - 👩‍🏫🧑‍🏫

# %%
# Dependencies
import requests
import json

# %%
# URL for GET requests to retrieve vehicle data
url = "https://api.spacexdata.com/v2/launchpads"

# %%
# Print the response object to the console
print(requests.get(url))
# Out:
# <Response [200]>

# %%
# Retrieving data and converting it into JSON
print(requests.get(url).json())

# API -> dictionary -> Pandas DataFrame
# API -> Clean with pandas
# Out:
# [{'padid': 5, 'id': 'vafb_slc_3w', 'name': 'VAFB SLC 3W', 'full_name': 'Vandenberg Air Force Base Space Launch Complex 3W', 'status': 'retired', 'location': {'name': 'Vandenberg Air Force Base', 'region': 'California', 'latitude': 34.6440904, 'longitude': -120.5931438}, 'vehicles_launched': ['Falcon 1'], 'attempted_launches': 0, 'successful_launches': 0, 'wikipedia': 'https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3', 'details': 'SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts.'}, {'padid': 2, 'id': 'ccafs_slc_40', 'name': 'CCAFS SLC 40', 'full_name': 'Cape Canaveral Air Force Station Space Launch Complex 40', 'status': 'active', 'location': {'name': 'Cape Canaveral', 'region': 'Florida', 'latitude': 28.5618571, 'longitude': -80.577366}, 'vehicles_launched': ['Falcon 9'], 'attempted_launches': 61, 'successful_launches': 59, 'wikipedia': 'https://en.wikipedia.org/wiki/Cape_Canaveral_Air_Force_Station_Space_Launch_Complex_40', 'details': 'SpaceX primary Falcon 9 launch pad, where all east coast Falcon 9s launched prior to the AMOS-6 anomaly. Initially used to launch Titan rockets for Lockheed Martin. Back online since CRS-13 on 2017-12-15.'}, {'padid': 8, 'id': 'stls', 'name': 'STLS', 'full_name': 'SpaceX South Texas Launch Site', 'status': 'under construction', 'location': {'name': 'Boca Chica Village', 'region': 'Texas', 'latitude': 25.9972641, 'longitude': -97.1560845}, 'vehicles_launched': ['Falcon 9'], 'attempted_launches': 0, 'successful_launches': 0, 'wikipedia': 'https://en.wikipedia.org/wiki/SpaceX_South_Texas_Launch_Site', 'details': 'SpaceX new launch site currently under construction to help keep up with the Falcon 9 and Heavy manifests. Expected to be completed in late 2018. Initially will be limited to 12 flights per year, and only GTO launches.'}, {'padid': 1, 'id': 'kwajalein_atoll', 'name': 'Kwajalein Atoll', 'full_name': 'Kwajalein Atoll Omelek Island', 'status': 'retired', 'location': {'name': 'Omelek Island', 'region': 'Marshall Islands', 'latitude': 9.0477206, 'longitude': 167.7431292}, 'vehicles_launched': ['Falcon 1'], 'attempted_launches': 5, 'successful_launches': 2, 'wikipedia': 'https://en.wikipedia.org/wiki/Omelek_Island', 'details': 'SpaceX original launch site, where all of the Falcon 1 launches occured. Abandoned as SpaceX decided against upgrading the pad to support Falcon 9.'}, {'padid': 6, 'id': 'vafb_slc_4e', 'name': 'VAFB SLC 4E', 'full_name': 'Vandenberg Air Force Base Space Launch Complex 4E', 'status': 'active', 'location': {'name': 'Vandenberg Air Force Base', 'region': 'California', 'latitude': 34.632093, 'longitude': -120.610829}, 'vehicles_launched': ['Falcon 9'], 'attempted_launches': 16, 'successful_launches': 16, 'wikipedia': 'https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_4', 'details': 'SpaceX primary west coast launch pad for polar orbits and sun synchronous orbits, primarily used for Iridium. Also intended to be capable of launching Falcon Heavy.'}, {'padid': 4, 'id': 'ksc_lc_39a', 'name': 'KSC LC 39A', 'full_name': 'Kennedy Space Center Historic Launch Complex 39A', 'status': 'active', 'location': {'name': 'Cape Canaveral', 'region': 'Florida', 'latitude': 28.6080585, 'longitude': -80.6039558}, 'vehicles_launched': ['Falcon 9', 'Falcon Heavy'], 'attempted_launches': 27, 'successful_launches': 26, 'wikipedia': 'https://en.wikipedia.org/wiki/Kennedy_Space_Center_Launch_Complex_39#Launch_Complex_39A', 'details': 'NASA historic launch pad that launched most of the Saturn V and Space Shuttle missions. Initially for Falcon Heavy launches, it is now launching all of SpaceX east coast missions due to the damage from the AMOS-6 anomaly. After SLC-40 repairs are complete, it will be upgraded to support Falcon Heavy, a process which will take about two months. In the future it will launch commercial crew missions and the Interplanetary Transport System ...

# %%
# Pretty Print the output of the JSON
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "attempted_launches": 0,
#         "details": "SpaceX original west coast launch pad for Falcon 1. Performed a static fire but was never used for a launch and abandoned due to scheduling conflicts.",
#         "full_name": "Vandenberg Air Force Base Space Launch Complex 3W",
#         "id": "vafb_slc_3w",
#         "location": {
#             "latitude": 34.6440904,
#             "longitude": -120.5931438,
#             "name": "Vandenberg Air Force Base",
#             "region": "California"
#         },
#         "name": "VAFB SLC 3W",
#         "padid": 5,
#         "status": "retired",
#         "successful_launches": 0,
#         "vehicles_launched": [
#             "Falcon 1"
#         ],
#         "wikipedia": "https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_3"
#     },
#     {
#         "attempted_launches": 61,
#         "details": "SpaceX primary Falcon 9 launch pad, where all east coast Falcon 9s launched prior to the AMOS-6 anomaly. Initially used to launch Titan rockets for Lockheed Martin. Back online since CRS-13 on 2017-12-15.",
#         "full_name": "Cape Canaveral Air Force Station Space Launch Complex 40",
#         "id": "ccafs_slc_40",
#         "location": {
#             "latitude": 28.5618571,
#             "longitude": -80.577366,
#             "name": "Cape Canaveral",
#             "region": "Florida"
#         },
#         "name": "CCAFS SLC 40",
#         "padid": 2,
#         "status": "active",
#         "successful_launches": 59,
#         "vehicles_launched": [
#             "Falcon 9"
#         ],
#         "wikipedia": "https://en.wikipedia.org/wiki/Cape_Canaveral_Air_Force_Station_Space_Launch_Complex_40"
#     },
#     {
#         "attempted_launches": 0,
#         "details": "SpaceX new launch site currently under construction to help keep up with the Falcon 9 and Heavy manifests. Expected to be completed in late 2018. Initially will be limited to 12 flights per year, and only GTO launches.",
#         "full_name": "SpaceX South Texas Launch Site",
#         "id": "stls",
#         "location": {
#             "latitude": 25.9972641,
#             "longitude": -97.1560845,
#             "name": "Boca Chica Village",
#             "region": "Texas"
#         },
#         "name": "STLS",
#         "padid": 8,
#         "status": "under construction",
#         "successful_launches": 0,
#         "vehicles_launched": [
#             "Falcon 9"
#         ],
#         "wikipedia": "https://en.wikipedia.org/wiki/SpaceX_South_Texas_Launch_Site"
#     },
#     {
#         "attempted_launches": 5,
#         "details": "SpaceX original launch site, where all of the Falcon 1 launches occured. Abandoned as SpaceX decided against upgrading the pad to support Falcon 9.",
#         "full_name": "Kwajalein Atoll Omelek Island",
#         "id": "kwajalein_atoll",
#         "location": {
#             "latitude": 9.0477206,
#             "longitude": 167.7431292,
#             "name": "Omelek Island",
#             "region": "Marshall Islands"
#         },
#         "name": "Kwajalein Atoll",
#         "padid": 1,
#         "status": "retired",
#         "successful_launches": 2,
#         "vehicles_launched": [
#             "Falcon 1"
#         ],
#         "wikipedia": "https://en.wikipedia.org/wiki/Omelek_Island"
#     },
#     {
#         "attempted_launches": 16,
#         "details": "SpaceX primary west coast launch pad for polar orbits and sun synchronous orbits, primarily used for Iridium. Also intended to be capable of launching Falcon Heavy.",
#         "full_name": "Vandenberg Air Force Base Space Launch Complex 4E",
#         "id": "vafb_slc_4e",
#         "location": {
#             "latitude": 34.632093,
#             "longitude": -120.610829,
#             "name": "Vandenberg Air Force Base",
#             "region": "California"
#         },
#         "name": "VAFB SLC 4E",
#         "padid": 6,
#         "status": "active",
#         "successful_launches": 16,
#         "vehicles_launched": [
#             "Falcon 9"
#         ],
#         "wikipedia": "https://en.wikipedia.org/wiki/Vandenberg_AFB_Space_Launch_Complex_4"
#     },
#     {
#         "attempted_launches": 27,
#         "details": "NASA historic launch pad that launched most of the Saturn V and Space Shuttle missions. Initially for Falcon Heavy launches, it is now launching all of SpaceX east coast missions due to the damage from the AMOS-6 anomaly. After SLC-40 repairs are complete, it will be upgraded to support Falcon Heavy, a process which will take about two months. In the future it will launch commercial crew missions and the Interplanetary Transport System.",
#         "full_name": "Kennedy Space Center Historic Launch Complex 39A",
#         "id": "ksc_lc_39a",
#         "location": {
#             "latitude": 28.6080585,
#             "longitude": -80.6039558,
#             "name": "Cape Canaveral",
#             "region": "Florida"
#         },
#         "name": "KSC LC 39A",
#         "padid": 4,
#         "status": "active",
#         "successful_launches": 26,
#         "vehicles_launched": [
#             "Falcon 9",
#             "Falcon Heavy"
#         ],
#         "wikipedia": "https://en.wikipedia.org/wiki/Kennedy_Space_Center_Launch_Complex_39#Launch_Complex_39A"
#     }
# ]

# %% [markdown]
# # Instructor Turn - 02 - NYT API - 👩‍🏫🧑‍🏫

# %%
# Dependencies
import requests
from pprint import pprint
from config import nytapi_key

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# %%
# Search for articles that mention granola
query = "granola"

# %%
# Build query URL
#query_url = url + "api-key=" + nytapi_key + "&q=" + query
# Option 2 fstrings 
query_url = f'{url}api-key={nytapi_key}&q={query}'
query_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=9gWoWYlkgE4JuC2GA6QahEyVqGrcUvlQ&q=granola'

# %%
# Request articles
articles = requests.get(query_url).json()
articles
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2022 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'abstract': '',
#     'web_url': 'https://cooking.nytimes.com/recipes/1014040-granola',
#     'snippet': '',
#     'lead_paragraph': 'I used to make a rich holiday granola, but often it burned and stuck to the baking sheets. One of the reasons: I used wheat germ, which browns more quickly than oats. Now I keep the heat low in my oven and line my backing sheets with parchment. Be sure to stir the granola every 10 to 15 minutes, and switch the trays from top to bottom each time you stir. If you want to make a smaller amount, you can halve this recipe.',
#     'multimedia': [{'rank': 0,
#       'subtype': 'watch308',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-watch308-v2.jpg',
#       'height': 348,
#       'width': 312,
#       'legacy': {},
#       'subType': 'watch308',
#       'crop_name': 'watch308'},
#      {'rank': 0,
#       'subtype': 'watch268',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-watch268-v2.jpg',
#       'height': 303,
#       'width': 272,
#       'legacy': {},
#       'subType': 'watch268',
#       'crop_name': 'watch268'},
#      {'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'widewidth': 190,
#        'wideheight': 126,
#        'wide': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-thumbWide.jpg'},
#       'subType': 'wide',
#       'crop_name': 'thumbWide'},
#      {'rank': 0,
#       'subtype': 'videoThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoThumb.jpg',
#       'height': 50,
#       'width': 75,
#       'legacy': {},
#       'subType': 'videoThumb',
#       'crop_name': 'videoThumb'},
#      {'rank': 0,
#       'subtype': 'videoLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoLarge.jpg',
#       'height': 507,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoLarge',
#       'crop_name': 'videoLarge'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo210',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-mediumThreeByTwo210.jpg',
#       'height': 140,
#       'width': 210,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo210',
#       'crop_name': 'mediumThreeByTwo210'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-mediumThreeByTwo225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo225',
#       'crop_name': 'mediumThreeByTwo225'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo440',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-mediumThreeByTwo440.jpg',
#       'height': 293,
#       'width': 440,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo440',
#       'crop_name': 'mediumThreeByTwo440'},
#      {'rank': 0,
#       'subtype': 'facebookJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-facebookJumbo-v2.jpg',
#       'height': 550,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'facebookJumbo',
#       'crop_name': 'facebookJumbo'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven1305',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoFifteenBySeven1305.jpg',
#       'height': 609,
#       'width': 1305,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven1305',
#       'crop_name': 'videoFifteenBySeven1305'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven2610',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoFifteenBySeven2610.jpg',
#       'height': 1218,
#       'width': 2610,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven2610',
#       'crop_name': 'videoFifteenBySeven2610'},
#      {'rank': 0,
#       'subtype': 'miniMoth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-miniMoth.jpg',
#       'height': 70,
#       'width': 151,
#       'legacy': {},
#       'subType': 'miniMoth',
#       'crop_name': 'miniMoth'},
#      {'rank': 0,
#       'subtype': 'windowsTile336H',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-windowsTile336H.jpg',
#       'height': 336,
#       'width': 694,
#       'legacy': {},
#       'subType': 'windowsTile336H',
#       'crop_name': 'windowsTile336H'},
#      {'rank': 0,
#       'subtype': 'verticalTwoByThree735',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-verticalTwoByThree735-v2.jpg',
#       'height': 1102,
#       'width': 735,
#       'legacy': {},
#       'subType': 'verticalTwoByThree735',
#       'crop_name': 'verticalTwoByThree735'},
#      {'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-articleLarge-v2.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {'xlarge': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-articleLarge-v2.jpg',
#        'xlargewidth': 600,
#        'xlargeheight': 400},
#       'subType': 'xlarge',
#       'crop_name': 'articleLarge'},
#      {'rank': 0,
#       'subtype': 'blog480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-blog480.jpg',
#       'height': 320,
#       'width': 480,
#       'legacy': {},
#       'subType': 'blog480',
#       'crop_name': 'blog480'},
#      {'rank': 0,
#       'subtype': 'blog427',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-blog427.jpg',
#       'height': 285,
#       'width': 427,
#       'legacy': {},
#       'subType': 'blog427',
#       'crop_name': 'blog427'},
#      {'rank': 0,
#       'subtype': 'tmagArticle',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-tmagArticle.jpg',
#       'height': 395,
#       'width': 592,
#       'legacy': {},
#       'subType': 'tmagArticle',
#       'crop_name': 'tmagArticle'},
#      {'rank': 0,
#       'subtype': 'jumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-jumbo.jpg',
#       'height': 683,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'jumbo',
#       'crop_name': 'jumbo'},
#      {'rank': 0,
#       'subtype': 'blog225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-blog225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'blog225',
#       'crop_name': 'blog225'},
#      {'rank': 0,
#       'subtype': 'master675',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-master675.jpg',
#       'height': 450,
#       'width': 675,
#       'legacy': {},
#       'subType': 'master675',
#       'crop_name': 'master675'},
#      {'rank': 0,
#       'subtype': 'master180',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-master180.jpg',
#       'height': 120,
#       'width': 180,
#       'legacy': {},
#       'subType': 'master180',
#       'crop_name': 'master180'},
#      {'rank': 0,
#       'subtype': 'popup',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-popup.jpg',
#       'height': 433,
#       'width': 650,
#       'legacy': {},
#       'subType': 'popup',
#       'crop_name': 'popup'},
#      {'rank': 0,
#       'subtype': 'blog533',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-blog533.jpg',
#       'height': 355,
#       'width': 533,
#       'legacy': {},
#       'subType': 'blog533',
#       'crop_name': 'blog533'},
#      {'rank': 0,
#       'subtype': 'tmagSF',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-tmagSF.jpg',
#       'height': 241,
#       'width': 362,
#       'legacy': {},
#       'subType': 'tmagSF',
#       'crop_name': 'tmagSF'},
#      {'rank': 0,
#       'subtype': 'slide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-slide.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {},
#       'subType': 'slide',
#       'crop_name': 'slide'},
#      {'rank': 0,
#       'subtype': 'superJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-superJumbo.jpg',
#       'height': 1365,
#       'width': 2048,
#       'legacy': {},
#       'subType': 'superJumbo',
#       'crop_name': 'superJumbo'},
#      {'rank': 0,
#       'subtype': 'master1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-master1050.jpg',
#       'height': 700,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'master1050',
#       'crop_name': 'master1050'},
#      {'rank': 0,
#       'subtype': 'master495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-master495.jpg',
#       'height': 330,
#       'width': 495,
#       'legacy': {},
#       'subType': 'master495',
#       'crop_name': 'master495'},
#      {'rank': 0,
#       'subtype': 'square320',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-square320.jpg',
#       'height': 320,
#       'width': 320,
#       'legacy': {},
#       'subType': 'square320',
#       'crop_name': 'square320'},
#      {'rank': 0,
#       'subtype': 'filmstrip',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-filmstrip.jpg',
#       'height': 190,
#       'width': 190,
#       'legacy': {},
#       'subType': 'filmstrip',
#       'crop_name': 'filmstrip'},
#      {'rank': 0,
#       'subtype': 'square640',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-square640.jpg',
#       'height': 640,
#       'width': 640,
#       'legacy': {},
#       'subType': 'square640',
#       'crop_name': 'square640'},
#      {'rank': 0,
#       'subtype': 'moth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-moth.jpg',
#       'height': 151,
#       'width': 151,
#       'legacy': {},
#       'subType': 'moth',
#       'crop_name': 'moth'},
#      {'rank': 0,
#       'subtype': 'mediumSquare149',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-mediumSquare149.jpg',
#       'height': 149,
#       'width': 149,
#       'legacy': {},
#       'subType': 'mediumSquare149',
#       'crop_name': 'mediumSquare149'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-articleInline.jpg',
#       'height': 127,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'hpSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-hpSmall.jpg',
#       'height': 109,
#       'width': 163,
#       'legacy': {},
#       'subType': 'hpSmall',
#       'crop_name': 'hpSmall'},
#      {'rank': 0,
#       'subtype': 'blogSmallInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-blogSmallInline.jpg',
#       'height': 101,
#       'width': 151,
#       'legacy': {},
#       'subType': 'blogSmallInline',
#       'crop_name': 'blogSmallInline'},
#      {'rank': 0,
#       'subtype': 'mediumFlexible177',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-mediumFlexible177.jpg',
#       'height': 118,
#       'width': 177,
#       'legacy': {},
#       'subType': 'mediumFlexible177',
#       'crop_name': 'mediumFlexible177'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-sfSpan-v2.jpg',
#       'height': 263,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'largeHorizontal375',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-largeHorizontal375.jpg',
#       'height': 250,
#       'width': 375,
#       'legacy': {},
#       'subType': 'largeHorizontal375',
#       'crop_name': 'largeHorizontal375'},
#      {'rank': 0,
#       'subtype': 'hpLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-hpLarge-v3.jpg',
#       'height': 287,
#       'width': 511,
#       'legacy': {},
#       'subType': 'hpLarge',
#       'crop_name': 'hpLarge'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen573',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-largeWidescreen573-v3.jpg',
#       'height': 322,
#       'width': 573,
#       'legacy': {},
#       'subType': 'largeWidescreen573',
#       'crop_name': 'largeWidescreen573'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-largeWidescreen1050-v2.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'largeWidescreen1050',
#       'crop_name': 'largeWidescreen1050'},
#      {'rank': 0,
#       'subtype': 'videoSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoSmall.jpg',
#       'height': 281,
#       'width': 500,
#       'legacy': {},
#       'subType': 'videoSmall',
#       'crop_name': 'videoSmall'},
#      {'rank': 0,
#       'subtype': 'videoHpMedium',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoHpMedium.jpg',
#       'height': 211,
#       'width': 375,
#       'legacy': {},
#       'subType': 'videoHpMedium',
#       'crop_name': 'videoHpMedium'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoSixteenByNine600.jpg',
#       'height': 338,
#       'width': 600,
#       'legacy': {},
#       'subType': 'videoSixteenByNine600',
#       'crop_name': 'videoSixteenByNine600'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine540',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoSixteenByNine540.jpg',
#       'height': 304,
#       'width': 540,
#       'legacy': {},
#       'subType': 'videoSixteenByNine540',
#       'crop_name': 'videoSixteenByNine540'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoSixteenByNine495.jpg',
#       'height': 278,
#       'width': 495,
#       'legacy': {},
#       'subType': 'videoSixteenByNine495',
#       'crop_name': 'videoSixteenByNine495'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine390',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoSixteenByNine390.jpg',
#       'height': 219,
#       'width': 390,
#       'legacy': {},
#       'subType': 'videoSixteenByNine390',
#       'crop_name': 'videoSixteenByNine390'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoSixteenByNine480.jpg',
#       'height': 270,
#       'width': 480,
#       'legacy': {},
#       'subType': 'videoSixteenByNine480',
#       'crop_name': 'videoSixteenByNine480'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine310',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoSixteenByNine310.jpg',
#       'height': 174,
#       'width': 310,
#       'legacy': {},
#       'subType': 'videoSixteenByNine310',
#       'crop_name': 'videoSixteenByNine310'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoSixteenByNine225.jpg',
#       'height': 126,
#       'width': 225,
#       'legacy': {},
#       'subType': 'videoSixteenByNine225',
#       'crop_name': 'videoSixteenByNine225'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine96',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoSixteenByNine96.jpg',
#       'height': 54,
#       'width': 96,
#       'legacy': {},
#       'subType': 'videoSixteenByNine96',
#       'crop_name': 'videoSixteenByNine96'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoSixteenByNine1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'videoSixteenByNine1050',
#       'crop_name': 'videoSixteenByNine1050'},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-thumbStandard-v2.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnail': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-thumbStandard-v2.jpg',
#        'thumbnailwidth': 75,
#        'thumbnailheight': 75},
#       'subType': 'thumbnail',
#       'crop_name': 'thumbStandard'},
#      {'rank': 0,
#       'subtype': 'thumbLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-thumbLarge.jpg',
#       'height': 150,
#       'width': 150,
#       'legacy': {},
#       'subType': 'thumbLarge',
#       'crop_name': 'thumbLarge'},
#      {'rank': 0,
#       'subtype': 'blogSmallThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-blogSmallThumb.jpg',
#       'height': 50,
#       'width': 50,
#       'legacy': {},
#       'subType': 'blogSmallThumb',
#       'crop_name': 'blogSmallThumb'}],
#     'headline': {'main': 'Granola',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': 'Granola',
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '2009-12-07T00:00:00+0000',
#     'document_type': 'recipe',
#     'news_desk': '',
#     'byline': {'original': 'Martha Rose Shulman',
#      'person': [{'firstname': 'Martha',
#        'middlename': 'Rose',
#        'lastname': 'Shulman',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Recipe',
#     '_id': 'nyt://recipe/03d3f15a-0671-5eac-841c-4af1c68ecb11',
#     'word_count': 0,
#     'uri': 'nyt://recipe/03d3f15a-0671-5eac-841c-4af1c68ecb11'},
#    {'abstract': 'This simple recipe has a deep coconut-spice flavor and a light, crunchy and delightfully clumpy texture.',
#     'web_url': 'https://www.nytimes.com/2016/05/11/dining/granola-recipe-clusters-video.html',
#     'snippet': 'This simple recipe has a deep coconut-spice flavor and a light, crunchy and delightfully clumpy texture.',
#     'lead_paragraph': 'Ever since I started making it several years ago, I’ve been loyal to one granola recipe that I picked up from a Brooklyn company called Early Bird.',
#     'print_section': 'D',
#     'print_page': '2',
#     'source': 'The New York Times',
#     'multimedia': [],
#     'headline': {'main': 'Granola That’s Packed With Clusters',
#      'kicker': 'A Good Appetite',
#      'content_kicker': None,
#      'print_headline': 'A Sticky Secret to Granola',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Cooking and Cookbooks',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Cereals', 'rank': 3, 'major': 'N'}],
#     'pub_date': '2016-05-06T16:22:41+0000',
#     'document_type': 'article',
#     'news_desk': 'Dining',
#     'section_name': 'Food',
#     'byline': {'original': 'By Melissa Clark',
#      'person': [{'firstname': 'Melissa',
#        'middlename': None,
#        'lastname': 'Clark',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'News',
#     '_id': 'nyt://article/f46d4350-8060-5d02-a013-ef486a26222c',
#     'word_count': 412,
#     'uri': 'nyt://article/f46d4350-8060-5d02-a013-ef486a26222c'},
#    {'abstract': '',
#     'web_url': 'https://cooking.nytimes.com/recipes/1014414-granola',
#     'snippet': '',
#     'lead_paragraph': 'This somewhat clumpy granola isn’t too sweet, so you can feel a little virtuous when you snack on it. It is best to eat it soon after baking, while the clumps still hold; they will eventually fall apart once you put the granola in a jar, but there are enough right after you bake it to qualify it as snacking food in addition to breakfast. Don’t stir it when you bake it and when it is done let it cool completely on the baking sheet; that is the trick to clumping. The technique of leaving a “donut hole” in the middle when you spread the granola on the baking sheet comes from www.brighteyedbaker.com. It helps the granola bake evenly. ',
#     'multimedia': [{'rank': 0,
#       'subtype': 'watch308',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-watch308-v2.jpg',
#       'height': 348,
#       'width': 312,
#       'legacy': {},
#       'subType': 'watch308',
#       'crop_name': 'watch308'},
#      {'rank': 0,
#       'subtype': 'watch268',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-watch268-v2.jpg',
#       'height': 303,
#       'width': 272,
#       'legacy': {},
#       'subType': 'watch268',
#       'crop_name': 'watch268'},
#      {'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-thumbWide-v3.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'widewidth': 190,
#        'wideheight': 126,
#        'wide': 'images/2012/12/17/health/19recipehealth/19recipehealth-thumbWide-v3.jpg'},
#       'subType': 'wide',
#       'crop_name': 'thumbWide'},
#      {'rank': 0,
#       'subtype': 'videoThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-videoThumb-v3.jpg',
#       'height': 50,
#       'width': 75,
#       'legacy': {},
#       'subType': 'videoThumb',
#       'crop_name': 'videoThumb'},
#      {'rank': 0,
#       'subtype': 'videoLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-videoLarge-v3.jpg',
#       'height': 507,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoLarge',
#       'crop_name': 'videoLarge'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo210',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-mediumThreeByTwo210-v2.jpg',
#       'height': 140,
#       'width': 210,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo210',
#       'crop_name': 'mediumThreeByTwo210'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-mediumThreeByTwo225-v2.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo225',
#       'crop_name': 'mediumThreeByTwo225'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo440',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-mediumThreeByTwo440-v3.jpg',
#       'height': 293,
#       'width': 440,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo440',
#       'crop_name': 'mediumThreeByTwo440'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-mediumThreeByTwo252-v2.jpg',
#       'height': 168,
#       'width': 252,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo252',
#       'crop_name': 'mediumThreeByTwo252'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo378',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-mediumThreeByTwo378-v2.jpg',
#       'height': 252,
#       'width': 378,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo378',
#       'crop_name': 'mediumThreeByTwo378'},
#      {'rank': 0,
#       'subtype': 'facebookJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-facebookJumbo-v2.jpg',
#       'height': 549,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'facebookJumbo',
#       'crop_name': 'facebookJumbo'},
#      {'rank': 0,
#       'subtype': 'miniMoth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-miniMoth.jpg',
#       'height': 70,
#       'width': 151,
#       'legacy': {},
#       'subType': 'miniMoth',
#       'crop_name': 'miniMoth'},
#      {'rank': 0,
#       'subtype': 'verticalTwoByThree735',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-verticalTwoByThree735-v2.jpg',
#       'height': 1101,
#       'width': 735,
#       'legacy': {},
#       'subType': 'verticalTwoByThree735',
#       'crop_name': 'verticalTwoByThree735'},
#      {'rank': 0,
#       'subtype': 'xlarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-articleLarge.jpg',
#       'height': 392,
#       'width': 600,
#       'legacy': {'xlarge': 'images/2012/12/17/health/19recipehealth/19recipehealth-articleLarge.jpg',
#        'xlargewidth': 600,
#        'xlargeheight': 392},
#       'subType': 'xlarge',
#       'crop_name': 'articleLarge'},
#      {'rank': 0,
#       'subtype': 'blog480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-blog480.jpg',
#       'height': 314,
#       'width': 480,
#       'legacy': {},
#       'subType': 'blog480',
#       'crop_name': 'blog480'},
#      {'rank': 0,
#       'subtype': 'blog427',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-blog427.jpg',
#       'height': 279,
#       'width': 427,
#       'legacy': {},
#       'subType': 'blog427',
#       'crop_name': 'blog427'},
#      {'rank': 0,
#       'subtype': 'tmagArticle',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-tmagArticle.jpg',
#       'height': 387,
#       'width': 592,
#       'legacy': {},
#       'subType': 'tmagArticle',
#       'crop_name': 'tmagArticle'},
#      {'rank': 0,
#       'subtype': 'jumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-jumbo.jpg',
#       'height': 669,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'jumbo',
#       'crop_name': 'jumbo'},
#      {'rank': 0,
#       'subtype': 'popup',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-popup.jpg',
#       'height': 425,
#       'width': 650,
#       'legacy': {},
#       'subType': 'popup',
#       'crop_name': 'popup'},
#      {'rank': 0,
#       'subtype': 'blog533',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-blog533.jpg',
#       'height': 348,
#       'width': 533,
#       'legacy': {},
#       'subType': 'blog533',
#       'crop_name': 'blog533'},
#      {'rank': 0,
#       'subtype': 'tmagSF',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-tmagSF.jpg',
#       'height': 237,
#       'width': 362,
#       'legacy': {},
#       'subType': 'tmagSF',
#       'crop_name': 'tmagSF'},
#      {'rank': 0,
#       'subtype': 'slide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-slide.jpg',
#       'height': 392,
#       'width': 600,
#       'legacy': {},
#       'subType': 'slide',
#       'crop_name': 'slide'},
#      {'rank': 0,
#       'subtype': 'superJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-superJumbo.jpg',
#       'height': 1339,
#       'width': 2048,
#       'legacy': {},
#       'subType': 'superJumbo',
#       'crop_name': 'superJumbo'},
#      {'rank': 0,
#       'subtype': 'square320',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-square320-v3.jpg',
#       'height': 320,
#       'width': 320,
#       'legacy': {},
#       'subType': 'square320',
#       'crop_name': 'square320'},
#      {'rank': 0,
#       'subtype': 'filmstrip',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-filmstrip-v3.jpg',
#       'height': 190,
#       'width': 190,
#       'legacy': {},
#       'subType': 'filmstrip',
#       'crop_name': 'filmstrip'},
#      {'rank': 0,
#       'subtype': 'square640',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-square640-v3.jpg',
#       'height': 640,
#       'width': 640,
#       'legacy': {},
#       'subType': 'square640',
#       'crop_name': 'square640'},
#      {'rank': 0,
#       'subtype': 'moth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-moth-v3.jpg',
#       'height': 151,
#       'width': 151,
#       'legacy': {},
#       'subType': 'moth',
#       'crop_name': 'moth'},
#      {'rank': 0,
#       'subtype': 'mediumSquare149',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-mediumSquare149-v2.jpg',
#       'height': 149,
#       'width': 149,
#       'legacy': {},
#       'subType': 'mediumSquare149',
#       'crop_name': 'mediumSquare149'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-articleInline.jpg',
#       'height': 124,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'hpSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-hpSmall.jpg',
#       'height': 107,
#       'width': 163,
#       'legacy': {},
#       'subType': 'hpSmall',
#       'crop_name': 'hpSmall'},
#      {'rank': 0,
#       'subtype': 'blogSmallInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-blogSmallInline.jpg',
#       'height': 99,
#       'width': 151,
#       'legacy': {},
#       'subType': 'blogSmallInline',
#       'crop_name': 'blogSmallInline'},
#      {'rank': 0,
#       'subtype': 'sfSpan',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-sfSpan-v3.jpg',
#       'height': 263,
#       'width': 395,
#       'legacy': {},
#       'subType': 'sfSpan',
#       'crop_name': 'sfSpan'},
#      {'rank': 0,
#       'subtype': 'largeHorizontalJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-largeHorizontalJumbo-v2.jpg',
#       'height': 682,
#       'width': 1024,
#       'legacy': {},
#       'subType': 'largeHorizontalJumbo',
#       'crop_name': 'largeHorizontalJumbo'},
#      {'rank': 0,
#       'subtype': 'largeHorizontal375',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-largeHorizontal375-v2.jpg',
#       'height': 250,
#       'width': 375,
#       'legacy': {},
#       'subType': 'largeHorizontal375',
#       'crop_name': 'largeHorizontal375'},
#      {'rank': 0,
#       'subtype': 'hpLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-hpLarge-v3.jpg',
#       'height': 287,
#       'width': 511,
#       'legacy': {},
#       'subType': 'hpLarge',
#       'crop_name': 'hpLarge'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen573',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-largeWidescreen573-v2.jpg',
#       'height': 322,
#       'width': 573,
#       'legacy': {},
#       'subType': 'largeWidescreen573',
#       'crop_name': 'largeWidescreen573'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-largeWidescreen1050-v2.jpg',
#       'height': 590,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'largeWidescreen1050',
#       'crop_name': 'largeWidescreen1050'},
#      {'rank': 0,
#       'subtype': 'videoSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-videoSmall-v3.jpg',
#       'height': 281,
#       'width': 500,
#       'legacy': {},
#       'subType': 'videoSmall',
#       'crop_name': 'videoSmall'},
#      {'rank': 0,
#       'subtype': 'videoHpMedium',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-videoHpMedium-v2.jpg',
#       'height': 211,
#       'width': 375,
#       'legacy': {},
#       'subType': 'videoHpMedium',
#       'crop_name': 'videoHpMedium'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-videoSixteenByNine600-v2.jpg',
#       'height': 338,
#       'width': 600,
#       'legacy': {},
#       'subType': 'videoSixteenByNine600',
#       'crop_name': 'videoSixteenByNine600'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine540',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-videoSixteenByNine540-v2.jpg',
#       'height': 304,
#       'width': 540,
#       'legacy': {},
#       'subType': 'videoSixteenByNine540',
#       'crop_name': 'videoSixteenByNine540'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-videoSixteenByNine495-v2.jpg',
#       'height': 278,
#       'width': 495,
#       'legacy': {},
#       'subType': 'videoSixteenByNine495',
#       'crop_name': 'videoSixteenByNine495'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine390',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-videoSixteenByNine390-v2.jpg',
#       'height': 219,
#       'width': 390,
#       'legacy': {},
#       'subType': 'videoSixteenByNine390',
#       'crop_name': 'videoSixteenByNine390'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-videoSixteenByNine480-v2.jpg',
#       'height': 270,
#       'width': 480,
#       'legacy': {},
#       'subType': 'videoSixteenByNine480',
#       'crop_name': 'videoSixteenByNine480'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine310',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-videoSixteenByNine310-v2.jpg',
#       'height': 174,
#       'width': 310,
#       'legacy': {},
#       'subType': 'videoSixteenByNine310',
#       'crop_name': 'videoSixteenByNine310'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-videoSixteenByNine225-v2.jpg',
#       'height': 126,
#       'width': 225,
#       'legacy': {},
#       'subType': 'videoSixteenByNine225',
#       'crop_name': 'videoSixteenByNine225'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine96',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-videoSixteenByNine96-v2.jpg',
#       'height': 54,
#       'width': 96,
#       'legacy': {},
#       'subType': 'videoSixteenByNine96',
#       'crop_name': 'videoSixteenByNine96'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-videoSixteenByNine768-v2.jpg',
#       'height': 432,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoSixteenByNine768',
#       'crop_name': 'videoSixteenByNine768'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine150',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-videoSixteenByNine150-v2.jpg',
#       'height': 84,
#       'width': 150,
#       'legacy': {},
#       'subType': 'videoSixteenByNine150',
#       'crop_name': 'videoSixteenByNine150'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-videoSixteenByNine1050-v2.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'videoSixteenByNine1050',
#       'crop_name': 'videoSixteenByNine1050'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine3000',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-videoSixteenByNine3000-v2.jpg',
#       'height': 1686,
#       'width': 3000,
#       'legacy': {},
#       'subType': 'videoSixteenByNine3000',
#       'crop_name': 'videoSixteenByNine3000'},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-thumbStandard-v3.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnail': 'images/2012/12/17/health/19recipehealth/19recipehealth-thumbStandard-v3.jpg',
#        'thumbnailwidth': 75,
#        'thumbnailheight': 75},
#       'subType': 'thumbnail',
#       'crop_name': 'thumbStandard'},
#      {'rank': 0,
#       'subtype': 'thumbLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-thumbLarge-v3.jpg',
#       'height': 150,
#       'width': 150,
#       'legacy': {},
#       'subType': 'thumbLarge',
#       'crop_name': 'thumbLarge'},
#      {'rank': 0,
#       'subtype': 'smallSquare252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-smallSquare252-v2.jpg',
#       'height': 252,
#       'width': 252,
#       'legacy': {},
#       'subType': 'smallSquare252',
#       'crop_name': 'smallSquare252'},
#      {'rank': 0,
#       'subtype': 'blogSmallThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-blogSmallThumb-v3.jpg',
#       'height': 50,
#       'width': 50,
#       'legacy': {},
#       'subType': 'blogSmallThumb',
#       'crop_name': 'blogSmallThumb'},
#      {'rank': 0,
#       'subtype': 'smallSquare168',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2012/12/17/health/19recipehealth/19recipehealth-smallSquare168-v2.jpg',
#       'height': 168,
#       'width': 168,
#       'legacy': {},
#       'subType': 'smallSquare168',
#       'crop_name': 'smallSquare168'}],
#     'headline': {'main': 'Granola',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': 'Granola',
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '2012-12-17T00:00:00+0000',
#     'document_type': 'recipe',
#     'news_desk': '',
#     'byline': {'original': 'Martha Rose Shulman',
#      'person': [{'firstname': 'Martha',
#        'middlename': 'Rose',
#        'lastname': 'Shulman',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Recipe',
#     '_id': 'nyt://recipe/29cf217b-d8d8-5f77-8559-5a02eb1b0b34',
#     'word_count': 0,
#     'uri': 'nyt://recipe/29cf217b-d8d8-5f77-8559-5a02eb1b0b34'},
#    {'abstract': 'There are two reasons for making your granola. One: it tastes better. Two: it contains better ingredients. Mark Bittman demonstrates.',
#     'web_url': 'https://www.nytimes.com/video/dining/1194817105861/making-granola.html',
#     'snippet': 'There are two reasons for making your granola. One: it tastes better. Two: it contains better ingredients. Mark Bittman demonstrates.',
#     'lead_paragraph': 'There are two reasons for making your granola. One: it tastes better. Two: it contains better ingredients. Mark Bittman demonstrates.',
#     'source': 'The New York Times',
#     'multimedia': [{'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2007/01/10/dining/Jan09MinimalistGr.190x126.fr.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'widewidth': 190,
#        'wideheight': 126,
#        'wide': 'images/2007/01/10/dining/Jan09MinimalistGr.190x126.fr.jpg'},
#       'subType': 'wide',
#       'crop_name': 'thumbWide'},
#      {'rank': 0,
#       'subtype': 'videoThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2007/01/10/dining/Jan09MinimalistGr.75x50.fr.jpg',
#       'height': 50,
#       'width': 75,
#       'legacy': {},
#       'subType': 'videoThumb',
#       'crop_name': 'videoThumb'},
#      {'rank': 0,
#       'subtype': 'videoSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2007/01/10/dining/Jan09MinimalistGr.312x176.fr.jpg',
#       'height': 176,
#       'width': 312,
#       'legacy': {},
#       'subType': 'videoSmall',
#       'crop_name': 'videoSmall'},
#      {'rank': 0,
#       'subtype': 'thumbnail',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2007/01/10/dining/Jan09MinimalistGr.75x75.fr.jpg',
#       'height': 75,
#       'width': 75,
#       'legacy': {'thumbnail': 'images/2007/01/10/dining/Jan09MinimalistGr.75x75.fr.jpg',
#        'thumbnailwidth': 75,
#        'thumbnailheight': 75},
#       'subType': 'thumbnail',
#       'crop_name': 'thumbStandard'}],
#     'headline': {'main': 'Making Granola',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'persons',
#       'value': 'Bittman, Mark',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Food', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Cooking and Cookbooks',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Recipes', 'rank': 4, 'major': 'N'}],
#     'pub_date': '2007-01-10T15:34:39+0000',
#     'document_type': 'multimedia',
#     'news_desk': '',
#     'section_name': 'Food',
#     'byline': {'original': None, 'person': [], 'organization': None},
#     'type_of_material': 'Video',
#     '_id': 'nyt://video/51a2ff31-65b6-5714-b96d-9969b1b527d8',
#     'word_count': 0,
#     'uri': 'nyt://video/51a2ff31-65b6-5714-b96d-9969b1b527d8'},
#    {'abstract': 'You can trace breakfast cereal back to the gruel-eating ancient Greeks.',
#     'web_url': 'https://www.nytimes.com/2012/03/25/magazine/who-made-that-granola.html',
#     'snippet': 'You can trace breakfast cereal back to the gruel-eating ancient Greeks.',
# ...
#       'crop_name': 'largeWidescreen573'},
#      {'rank': 0,
#       'subtype': 'largeWidescreen1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-largeWidescreen1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'largeWidescreen1050',
#       'crop_name': 'largeWidescreen1050'},
#      {'rank': 0,
#       'subtype': 'wide',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-thumbWide.jpg',
#       'height': 126,
#       'width': 190,
#       'legacy': {'widewidth': 190,
#        'wideheight': 126,
#        'wide': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-thumbWide.jpg'},
#       'subType': 'wide',
#       'crop_name': 'thumbWide'},
#      {'rank': 0,
#       'subtype': 'videoThumb',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoThumb.jpg',
#       'height': 50,
#       'width': 75,
#       'legacy': {},
#       'subType': 'videoThumb',
#       'crop_name': 'videoThumb'},
#      {'rank': 0,
#       'subtype': 'videoLarge',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoLarge.jpg',
#       'height': 507,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoLarge',
#       'crop_name': 'videoLarge'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo210',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-mediumThreeByTwo210.jpg',
#       'height': 140,
#       'width': 210,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo210',
#       'crop_name': 'mediumThreeByTwo210'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-mediumThreeByTwo225.jpg',
#       'height': 150,
#       'width': 225,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo225',
#       'crop_name': 'mediumThreeByTwo225'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo440',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-mediumThreeByTwo440.jpg',
#       'height': 293,
#       'width': 440,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo440',
#       'crop_name': 'mediumThreeByTwo440'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo252',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-mediumThreeByTwo252.jpg',
#       'height': 168,
#       'width': 252,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo252',
#       'crop_name': 'mediumThreeByTwo252'},
#      {'rank': 0,
#       'subtype': 'mediumThreeByTwo378',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-mediumThreeByTwo378.jpg',
#       'height': 252,
#       'width': 378,
#       'legacy': {},
#       'subType': 'mediumThreeByTwo378',
#       'crop_name': 'mediumThreeByTwo378'},
#      {'rank': 0,
#       'subtype': 'threeByTwoLargeAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-threeByTwoLargeAt2X.jpg',
#       'height': 3475,
#       'width': 5212,
#       'legacy': {},
#       'subType': 'threeByTwoLargeAt2X',
#       'crop_name': 'threeByTwoLargeAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoMediumAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-threeByTwoMediumAt2X.jpg',
#       'height': 1000,
#       'width': 1500,
#       'legacy': {},
#       'subType': 'threeByTwoMediumAt2X',
#       'crop_name': 'threeByTwoMediumAt2X'},
#      {'rank': 0,
#       'subtype': 'threeByTwoSmallAt2X',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-threeByTwoSmallAt2X.jpg',
#       'height': 400,
#       'width': 600,
#       'legacy': {},
#       'subType': 'threeByTwoSmallAt2X',
#       'crop_name': 'threeByTwoSmallAt2X'},
#      {'rank': 0,
#       'subtype': 'articleInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-articleInline.jpg',
#       'height': 121,
#       'width': 190,
#       'legacy': {},
#       'subType': 'articleInline',
#       'crop_name': 'articleInline'},
#      {'rank': 0,
#       'subtype': 'hpSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-hpSmall.jpg',
#       'height': 104,
#       'width': 163,
#       'legacy': {},
#       'subType': 'hpSmall',
#       'crop_name': 'hpSmall'},
#      {'rank': 0,
#       'subtype': 'blogSmallInline',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-blogSmallInline.jpg',
#       'height': 96,
#       'width': 151,
#       'legacy': {},
#       'subType': 'blogSmallInline',
#       'crop_name': 'blogSmallInline'},
#      {'rank': 0,
#       'subtype': 'mediumFlexible177',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-mediumFlexible177.jpg',
#       'height': 113,
#       'width': 177,
#       'legacy': {},
#       'subType': 'mediumFlexible177',
#       'crop_name': 'mediumFlexible177'},
#      {'rank': 0,
#       'subtype': 'videoSmall',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoSmall.jpg',
#       'height': 281,
#       'width': 500,
#       'legacy': {},
#       'subType': 'videoSmall',
#       'crop_name': 'videoSmall'},
#      {'rank': 0,
#       'subtype': 'videoHpMedium',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoHpMedium.jpg',
#       'height': 211,
#       'width': 375,
#       'legacy': {},
#       'subType': 'videoHpMedium',
#       'crop_name': 'videoHpMedium'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoSixteenByNine600.jpg',
#       'height': 338,
#       'width': 600,
#       'legacy': {},
#       'subType': 'videoSixteenByNine600',
#       'crop_name': 'videoSixteenByNine600'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine540',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoSixteenByNine540.jpg',
#       'height': 304,
#       'width': 540,
#       'legacy': {},
#       'subType': 'videoSixteenByNine540',
#       'crop_name': 'videoSixteenByNine540'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine495',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoSixteenByNine495.jpg',
#       'height': 278,
#       'width': 495,
#       'legacy': {},
#       'subType': 'videoSixteenByNine495',
#       'crop_name': 'videoSixteenByNine495'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine390',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoSixteenByNine390.jpg',
#       'height': 219,
#       'width': 390,
#       'legacy': {},
#       'subType': 'videoSixteenByNine390',
#       'crop_name': 'videoSixteenByNine390'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine1050',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoSixteenByNine1050.jpg',
#       'height': 591,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'videoSixteenByNine1050',
#       'crop_name': 'videoSixteenByNine1050'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine480',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoSixteenByNine480.jpg',
#       'height': 270,
#       'width': 480,
#       'legacy': {},
#       'subType': 'videoSixteenByNine480',
#       'crop_name': 'videoSixteenByNine480'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine310',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoSixteenByNine310.jpg',
#       'height': 174,
#       'width': 310,
#       'legacy': {},
#       'subType': 'videoSixteenByNine310',
#       'crop_name': 'videoSixteenByNine310'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine225',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoSixteenByNine225.jpg',
#       'height': 126,
#       'width': 225,
#       'legacy': {},
#       'subType': 'videoSixteenByNine225',
#       'crop_name': 'videoSixteenByNine225'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine96',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoSixteenByNine96.jpg',
#       'height': 54,
#       'width': 96,
#       'legacy': {},
#       'subType': 'videoSixteenByNine96',
#       'crop_name': 'videoSixteenByNine96'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine3000',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoSixteenByNine3000.jpg',
#       'height': 1688,
#       'width': 3000,
#       'legacy': {},
#       'subType': 'videoSixteenByNine3000',
#       'crop_name': 'videoSixteenByNine3000'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine768',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoSixteenByNine768.jpg',
#       'height': 432,
#       'width': 768,
#       'legacy': {},
#       'subType': 'videoSixteenByNine768',
#       'crop_name': 'videoSixteenByNine768'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNine150',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoSixteenByNine150.jpg',
#       'height': 84,
#       'width': 150,
#       'legacy': {},
#       'subType': 'videoSixteenByNine150',
#       'crop_name': 'videoSixteenByNine150'},
#      {'rank': 0,
#       'subtype': 'videoSixteenByNineJumbo1600',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoSixteenByNineJumbo1600.jpg',
#       'height': 900,
#       'width': 1600,
#       'legacy': {},
#       'subType': 'videoSixteenByNineJumbo1600',
#       'crop_name': 'videoSixteenByNineJumbo1600'},
#      {'rank': 0,
#       'subtype': 'miniMoth',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-miniMoth.jpg',
#       'height': 70,
#       'width': 151,
#       'legacy': {},
#       'subType': 'miniMoth',
#       'crop_name': 'miniMoth'},
#      {'rank': 0,
#       'subtype': 'windowsTile336H',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-windowsTile336H.jpg',
#       'height': 336,
#       'width': 694,
#       'legacy': {},
#       'subType': 'windowsTile336H',
#       'crop_name': 'windowsTile336H'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven1305',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoFifteenBySeven1305.jpg',
#       'height': 609,
#       'width': 1305,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven1305',
#       'crop_name': 'videoFifteenBySeven1305'},
#      {'rank': 0,
#       'subtype': 'videoFifteenBySeven2610',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-videoFifteenBySeven2610.jpg',
#       'height': 1218,
#       'width': 2610,
#       'legacy': {},
#       'subType': 'videoFifteenBySeven2610',
#       'crop_name': 'videoFifteenBySeven2610'},
#      {'rank': 0,
#       'subtype': 'facebookJumbo',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-facebookJumbo.jpg',
#       'height': 550,
#       'width': 1050,
#       'legacy': {},
#       'subType': 'facebookJumbo',
#       'crop_name': 'facebookJumbo'},
#      {'rank': 0,
#       'subtype': 'watch308',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-watch308.jpg',
#       'height': 348,
#       'width': 312,
#       'legacy': {},
#       'subType': 'watch308',
#       'crop_name': 'watch308'},
#      {'rank': 0,
#       'subtype': 'watch268',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-watch268.jpg',
#       'height': 303,
#       'width': 272,
#       'legacy': {},
#       'subType': 'watch268',
#       'crop_name': 'watch268'},
#      {'rank': 0,
#       'subtype': 'verticalTwoByThree735',
#       'caption': None,
#       'credit': None,
#       'type': 'image',
#       'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-verticalTwoByThree735.jpg',
#       'height': 1102,
#       'width': 735,
#       'legacy': {},
#       'subType': 'verticalTwoByThree735',
#       'crop_name': 'verticalTwoByThree735'}],
#     'headline': {'main': 'Granola Bites',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': None,
#      'name': 'Granola Bites',
#      'seo': None,
#      'sub': None},
#     'keywords': [],
#     'pub_date': '2018-08-24T00:00:00+0000',
#     'document_type': 'recipe',
#     'news_desk': '',
#     'byline': {'original': 'Genevieve Ko',
#      'person': [{'firstname': 'Genevieve',
#        'middlename': None,
#        'lastname': 'Ko',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'type_of_material': 'Recipe',
#     '_id': 'nyt://recipe/13c32ef2-bc46-549f-a81b-a4256b1fa716',
#     'word_count': 0,
#     'uri': 'nyt://recipe/13c32ef2-bc46-549f-a81b-a4256b1fa716'}],
#   'meta': {'hits': 2125, 'offset': 0, 'time': 39}}}

# %%
#print(articles)
# The "response" property in articles contains the actual articles
# list comprehension.
articles_list = [article for article in articles["response"]["docs"]]
print(articles_list)
# Out:
# [{'abstract': '', 'web_url': 'https://cooking.nytimes.com/recipes/1014040-granola', 'snippet': '', 'lead_paragraph': 'I used to make a rich holiday granola, but often it burned and stuck to the baking sheets. One of the reasons: I used wheat germ, which browns more quickly than oats. Now I keep the heat low in my oven and line my backing sheets with parchment. Be sure to stir the granola every 10 to 15 minutes, and switch the trays from top to bottom each time you stir. If you want to make a smaller amount, you can halve this recipe.', 'multimedia': [{'rank': 0, 'subtype': 'watch308', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-watch308-v2.jpg', 'height': 348, 'width': 312, 'legacy': {}, 'subType': 'watch308', 'crop_name': 'watch308'}, {'rank': 0, 'subtype': 'watch268', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-watch268-v2.jpg', 'height': 303, 'width': 272, 'legacy': {}, 'subType': 'watch268', 'crop_name': 'watch268'}, {'rank': 0, 'subtype': 'wide', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-thumbWide.jpg', 'height': 126, 'width': 190, 'legacy': {'widewidth': 190, 'wideheight': 126, 'wide': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-thumbWide.jpg'}, 'subType': 'wide', 'crop_name': 'thumbWide'}, {'rank': 0, 'subtype': 'videoThumb', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoThumb.jpg', 'height': 50, 'width': 75, 'legacy': {}, 'subType': 'videoThumb', 'crop_name': 'videoThumb'}, {'rank': 0, 'subtype': 'videoLarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoLarge.jpg', 'height': 507, 'width': 768, 'legacy': {}, 'subType': 'videoLarge', 'crop_name': 'videoLarge'}, {'rank': 0, 'subtype': 'mediumThreeByTwo210', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-mediumThreeByTwo210.jpg', 'height': 140, 'width': 210, 'legacy': {}, 'subType': 'mediumThreeByTwo210', 'crop_name': 'mediumThreeByTwo210'}, {'rank': 0, 'subtype': 'mediumThreeByTwo225', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-mediumThreeByTwo225.jpg', 'height': 150, 'width': 225, 'legacy': {}, 'subType': 'mediumThreeByTwo225', 'crop_name': 'mediumThreeByTwo225'}, {'rank': 0, 'subtype': 'mediumThreeByTwo440', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-mediumThreeByTwo440.jpg', 'height': 293, 'width': 440, 'legacy': {}, 'subType': 'mediumThreeByTwo440', 'crop_name': 'mediumThreeByTwo440'}, {'rank': 0, 'subtype': 'facebookJumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-facebookJumbo-v2.jpg', 'height': 550, 'width': 1050, 'legacy': {}, 'subType': 'facebookJumbo', 'crop_name': 'facebookJumbo'}, {'rank': 0, 'subtype': 'videoFifteenBySeven1305', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoFifteenBySeven1305.jpg', 'height': 609, 'width': 1305, 'legacy': {}, 'subType': 'videoFifteenBySeven1305', 'crop_name': 'videoFifteenBySeven1305'}, {'rank': 0, 'subtype': 'videoFifteenBySeven2610', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2009/12/07/health/07recipehealth_600/07recipehealth_600-videoFifteenBySeven2610.jpg', 'height': 1218, 'width': 2610, 'legacy': {}, 'subType': 'videoFifteenBySeven2610', 'crop_name': 'videoFifteenBySeven2610'}, {'rank': 0, 'subtype': 'miniMoth', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2009/12/07/health/07recipehealth_6 ...

# %%
import pandas as pd

pd.DataFrame(articles_list)
# Out:
#                                             abstract  \
# 0
# 1  This simple recipe has a deep coconut-spice fl...
# 2
# 3  There are two reasons for making your granola....
# 4  You can trace breakfast cereal back to the gru...
# 5  Wandering the aisles at the Whole Foods store ...
# 6                             Adapted from Heartbeat
# 7
# 8
# 9
#
#                                              web_url  \
# 0  https://cooking.nytimes.com/recipes/1014040-gr...
# 1  https://www.nytimes.com/2016/05/11/dining/gran...
# 2  https://cooking.nytimes.com/recipes/1014414-gr...
# 3  https://www.nytimes.com/video/dining/119481710...
# 4  https://www.nytimes.com/2012/03/25/magazine/wh...
# 5  https://www.nytimes.com/1999/01/24/nyregion/th...
# 6  https://www.nytimes.com/2000/11/22/living/gran...
# 7  https://cooking.nytimes.com/recipes/1020980-st...
# 8  https://cooking.nytimes.com/recipes/1012921-gr...
# 9  https://cooking.nytimes.com/recipes/1019514-gr...
#
#                                              snippet  \
# 0
# 1  This simple recipe has a deep coconut-spice fl...
# 2
# 3  There are two reasons for making your granola....
# 4  You can trace breakfast cereal back to the gru...
# 5
# 6                             Adapted from Heartbeat
# 7
# 8
# 9
#
#                                       lead_paragraph  \
# 0  I used to make a rich holiday granola, but oft...
# 1  Ever since I started making it several years a...
# 2  This somewhat clumpy granola isn’t too sweet, ...
# 3  There are two reasons for making your granola....
# 4  You can trace breakfast cereal back to gruel-e...
# 5  Wandering the aisles at the Whole Foods store ...
# 6                            Adapted from Heartbeat
# 7  Studded with pink freeze-dried strawberries an...
# 8  These substantial breakfast muffins are sort o...
# 9  These chewy-crunchy, salty-sweet breakfast bal...
#
#                                           multimedia  \
# 0  [{'rank': 0, 'subtype': 'watch308', 'caption':...
# 1                                                 []
# 2  [{'rank': 0, 'subtype': 'watch308', 'caption':...
# 3  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
# 4  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 5                                                 []
# 6                                                 []
# 7  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 8  [{'rank': 0, 'subtype': 'watch308', 'caption':...
# 9  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             headline  \
# 0  {'main': 'Granola', 'kicker': None, 'content_k...
# 1  {'main': 'Granola That’s Packed With Clusters'...
# 2  {'main': 'Granola', 'kicker': None, 'content_k...
# 3  {'main': 'Making Granola', 'kicker': None, 'co...
# 4  {'main': 'Who Made That Granola?', 'kicker': '...
# 5  {'main': 'They Stand by Their Granola', 'kicke...
# 6  {'main': 'Granola', 'kicker': None, 'content_k...
# 7  {'main': 'Strawberry Granola', 'kicker': None,...
# 8  {'main': 'Granola Muffins', 'kicker': None, 'c...
# 9  {'main': 'Granola Bites', 'kicker': None, 'con...
#
#                                             keywords  \
# 0                                                 []
# 1  [{'name': 'subject', 'value': 'Cooking and Coo...
# 2                                                 []
# 3  [{'name': 'persons', 'value': 'Bittman, Mark',...
# 4  [{'name': 'subject', 'value': 'Diet and Nutrit...
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9                                                 []
#
#                    pub_date document_type          news_desk  \
# 0  2009-12-07T00:00:00+0000        recipe
# 1  2016-05-06T16:22:41+0000       article             Dining
# 2  2012-12-17T00:00:00+0000        recipe
# 3  2007-01-10T15:34:39+0000    multimedia
# 4  2012-03-23T14:00:21+0000       article           Magazine
# 5  1999-01-24T05:00:00+0000       article  Metropolitan Desk
# 6  2000-11-22T05:00:00+0000       article               None
# 7  2020-03-31T00:00:00+0000        recipe
# 8  2009-12-09T00:00:00+0000        recipe
# 9  2018-08-24T00:00:00+0000        recipe
#
#                                               byline type_of_material  \
# 0  {'original': 'Martha Rose Shulman', 'person': ...           Recipe
# 1  {'original': 'By Melissa Clark', 'person': [{'...             News
# 2  {'original': 'Martha Rose Shulman', 'person': ...           Recipe
# 3  {'original': None, 'person': [], 'organization...            Video
# 4  {'original': 'By Hilary Greenbaum and Dana Rub...             News
# 5  {'original': 'By Ginger Thompson', 'person': [...             News
# 6  {'original': 'By', 'person': [], 'organization...             News
# 7  {'original': 'Daniela Galarza', 'person': [{'f...           Recipe
# 8  {'original': 'Martha Rose Shulman', 'person': ...           Recipe
# 9  {'original': 'Genevieve Ko', 'person': [{'firs...           Recipe
#
#                                                  _id  word_count  \
# 0  nyt://recipe/03d3f15a-0671-5eac-841c-4af1c68ecb11           0
# 1  nyt://article/f46d4350-8060-5d02-a013-ef486a26...         412
# 2  nyt://recipe/29cf217b-d8d8-5f77-8559-5a02eb1b0b34           0
# 3   nyt://video/51a2ff31-65b6-5714-b96d-9969b1b527d8           0
# 4  nyt://article/1dc7502e-447e-52dc-9dcc-d8e9c15c...         553
# 5  nyt://article/dcf0c898-b803-5fed-a6e5-ecc42dcc...         721
# 6  nyt://article/1272b8c0-5446-5245-a90e-e88a2ddc...         183
# 7  nyt://recipe/6f4ef5de-f156-5651-8c3f-bc0bef925d5a           0
# 8  nyt://recipe/2c91b552-12f4-5a6c-b14e-29018042d80c           0
# 9  nyt://recipe/13c32ef2-bc46-549f-a81b-a4256b1fa716           0
#
#                                                  uri print_section print_page  \
# 0  nyt://recipe/03d3f15a-0671-5eac-841c-4af1c68ecb11           NaN        NaN
# 1  nyt://article/f46d4350-8060-5d02-a013-ef486a26...             D          2
# 2  nyt://recipe/29cf217b-d8d8-5f77-8559-5a02eb1b0b34           NaN        NaN
# 3   nyt://video/51a2ff31-65b6-5714-b96d-9969b1b527d8           NaN        NaN
# 4  nyt://article/1dc7502e-447e-52dc-9dcc-d8e9c15c...            MM         22
# 5  nyt://article/dcf0c898-b803-5fed-a6e5-ecc42dcc...             1         33
# 6  nyt://article/1272b8c0-5446-5245-a90e-e88a2ddc...           NaN        NaN
# 7  nyt://recipe/6f4ef5de-f156-5651-8c3f-bc0bef925d5a           NaN        NaN
# 8  nyt://recipe/2c91b552-12f4-5a6c-b14e-29018042d80c           NaN        NaN
# 9  nyt://recipe/13c32ef2-bc46-549f-a81b-a4256b1fa716           NaN        NaN
#
#                source section_name
# 0                 NaN          NaN
# 1  The New York Times         Food
# 2                 NaN          NaN
# 3  The New York Times         Food
# 4  The New York Times     Magazine
# 5  The New York Times     New York
# 6  The New York Times        Style
# 7                 NaN          NaN
# 8                 NaN          NaN
# 9                 NaN          NaN

# %%
# Print the web_url of each stored article
print("Your Reading List")
for article in articles_list:
    print(article["web_url"])

# %% [markdown]
# # Student Turn - 03 - Retrieve Articles - 👩‍🎓👨‍🎓

# %% [markdown]
# # Instructions
#
# * Save the NYT API endpoint to a variable. Make sure you include the right query parameter to retrieve JSON data!
#
# * Register for and save your API Key to a variable.
#
# * Decide on a search term, and save it to a variable.
#
# * Limit your search to articles published within a range of dates—for example, only articles published in 2014. _Hint_: Read the documentation on `end_date`.
#
# * Build your query URL, and save it to a variable.
#
# * Retrieve a response from the NYT API with a GET request.
#
# * Take a look at the documentation. How do you get a hold of the articles in the response?
#
# * Traverse through the returned JSON to retrieve the list of articles and store it in a variable.
#
# * Print a `snippet` from each article and separate using dashes (`-`).
#
# * As a bonus, try to figure out how we could get 30 results. _Hint_: Look up the `page` query parameter. If you get a message saying you've exceeded your rate limit, don't fret—you've solved the problem.
#
# * **Warning:** Be sure not to print out any of the query URLs. The query URLs will include your API key and if pushed to a public repository, it becomes a security risk for you as someone could steal and use your key.
#
# - - -

# %%
# Dependencies
import requests
from config import nytapi_key
import time

#url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Store a search term
query = input("Enter the term you'd like to search: ")

# Search for articles published between a begin and end date
begin_date = input("Enter the begin date in format YYYYMMDD: ")
end_date = input("Enter the end date in format YYYYMMDD: ")

query_url = f"{url}api-key={nytapi_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
query_url
# Out:
# Enter the term you'd like to search: cybersecurity
# Enter the begin date in format YYYYMMDD: 20220101
# Enter the end date in format YYYYMMDD: 20220131
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=9gWoWYlkgE4JuC2GA6QahEyVqGrcUvlQ&q=cybersecurity&begin_date=20220101&end_date=20220131'

# %%
# Retrieve articles
articles = requests.get(query_url).json()
articles_list = articles["response"]["docs"]

articles_list
# Out:
# [{'abstract': 'Audrey Strauss is returning to the law firm Fried Frank, and Cyrus Vance Jr. is starting a new job as a partner at the law firm Baker McKenzie.',
#   'web_url': 'https://www.nytimes.com/2022/01/31/business/audrey-strass-cyrus-vance.html',
#   'snippet': 'Audrey Strauss is returning to the law firm Fried Frank, and Cyrus Vance Jr. is starting a new job as a partner at the law firm Baker McKenzie.',
#   'lead_paragraph': 'Audrey Strauss and Cyrus R. Vance Jr., two prosecutors in New York whose offices have tangled with former President Donald J. Trump, are heading back to private legal practice.',
#   'print_section': 'B',
#   'print_page': '6',
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-articleLarge.jpg',
#     'height': 900,
#     'width': 600,
#     'legacy': {'xlarge': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-articleLarge.jpg',
#      'xlargewidth': 600,
#      'xlargeheight': 900},
#     'subType': 'xlarge',
#     'crop_name': 'articleLarge'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-popup.jpg',
#     'height': 500,
#     'width': 334,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'blog480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-blog480.jpg',
#     'height': 720,
#     'width': 480,
#     'legacy': {},
#     'subType': 'blog480',
#     'crop_name': 'blog480'},
#    {'rank': 0,
#     'subtype': 'blog533',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-blog533.jpg',
#     'height': 800,
#     'width': 533,
#     'legacy': {},
#     'subType': 'blog533',
#     'crop_name': 'blog533'},
#    {'rank': 0,
#     'subtype': 'blog427',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-blog427.jpg',
#     'height': 641,
#     'width': 427,
#     'legacy': {},
#     'subType': 'blog427',
#     'crop_name': 'blog427'},
#    {'rank': 0,
#     'subtype': 'tmagSF',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-tmagSF.jpg',
#     'height': 543,
#     'width': 362,
#     'legacy': {},
#     'subType': 'tmagSF',
#     'crop_name': 'tmagSF'},
#    {'rank': 0,
#     'subtype': 'tmagArticle',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-tmagArticle.jpg',
#     'height': 888,
#     'width': 592,
#     'legacy': {},
#     'subType': 'tmagArticle',
#     'crop_name': 'tmagArticle'},
#    {'rank': 0,
#     'subtype': 'slide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-slide.jpg',
#     'height': 500,
#     'width': 334,
#     'legacy': {},
#     'subType': 'slide',
#     'crop_name': 'slide'},
#    {'rank': 0,
#     'subtype': 'jumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-jumbo.jpg',
#     'height': 1024,
#     'width': 683,
#     'legacy': {},
#     'subType': 'jumbo',
#     'crop_name': 'jumbo'},
#    {'rank': 0,
#     'subtype': 'superJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-superJumbo.jpg',
#     'height': 2048,
#     'width': 1366,
#     'legacy': {},
#     'subType': 'superJumbo',
#     'crop_name': 'superJumbo'},
#    {'rank': 0,
#     'subtype': 'blog225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-blog225.jpg',
#     'height': 338,
#     'width': 225,
#     'legacy': {},
#     'subType': 'blog225',
#     'crop_name': 'blog225'},
#    {'rank': 0,
#     'subtype': 'master1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-master1050.jpg',
#     'height': 1575,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'master1050',
#     'crop_name': 'master1050'},
#    {'rank': 0,
#     'subtype': 'master675',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-master675.jpg',
#     'height': 1013,
#     'width': 675,
#     'legacy': {},
#     'subType': 'master675',
#     'crop_name': 'master675'},
#    {'rank': 0,
#     'subtype': 'master495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-master495.jpg',
#     'height': 743,
#     'width': 495,
#     'legacy': {},
#     'subType': 'master495',
#     'crop_name': 'master495'},
#    {'rank': 0,
#     'subtype': 'master180',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-master180.jpg',
#     'height': 270,
#     'width': 180,
#     'legacy': {},
#     'subType': 'master180',
#     'crop_name': 'master180'},
#    {'rank': 0,
#     'subtype': 'master315',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-master315.jpg',
#     'height': 473,
#     'width': 315,
#     'legacy': {},
#     'subType': 'master315',
#     'crop_name': 'master315'},
#    {'rank': 0,
#     'subtype': 'master768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-master768.jpg',
#     'height': 1152,
#     'width': 768,
#     'legacy': {},
#     'subType': 'master768',
#     'crop_name': 'master768'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnail': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-thumbStandard.jpg',
#      'thumbnailwidth': 75,
#      'thumbnailheight': 75},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'},
#    {'rank': 0,
#     'subtype': 'blogSmallThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-blogSmallThumb.jpg',
#     'height': 50,
#     'width': 50,
#     'legacy': {},
#     'subType': 'blogSmallThumb',
#     'crop_name': 'blogSmallThumb'},
#    {'rank': 0,
#     'subtype': 'thumbLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-thumbLarge.jpg',
#     'height': 150,
#     'width': 150,
#     'legacy': {},
#     'subType': 'thumbLarge',
#     'crop_name': 'thumbLarge'},
#    {'rank': 0,
#     'subtype': 'smallSquare168',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-smallSquare168.jpg',
#     'height': 168,
#     'width': 168,
#     'legacy': {},
#     'subType': 'smallSquare168',
#     'crop_name': 'smallSquare168'},
#    {'rank': 0,
#     'subtype': 'smallSquare252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-smallSquare252.jpg',
#     'height': 252,
#     'width': 252,
#     'legacy': {},
#     'subType': 'smallSquare252',
#     'crop_name': 'smallSquare252'},
#    {'rank': 0,
#     'subtype': 'square320',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-square320.jpg',
#     'height': 320,
#     'width': 320,
#     'legacy': {},
#     'subType': 'square320',
#     'crop_name': 'square320'},
#    {'rank': 0,
#     'subtype': 'moth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-moth.jpg',
#     'height': 151,
#     'width': 151,
#     'legacy': {},
#     'subType': 'moth',
#     'crop_name': 'moth'},
#    {'rank': 0,
#     'subtype': 'filmstrip',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-filmstrip.jpg',
#     'height': 190,
#     'width': 190,
#     'legacy': {},
#     'subType': 'filmstrip',
#     'crop_name': 'filmstrip'},
#    {'rank': 0,
#     'subtype': 'square640',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-square640.jpg',
#     'height': 640,
#     'width': 640,
#     'legacy': {},
#     'subType': 'square640',
#     'crop_name': 'square640'},
#    {'rank': 0,
#     'subtype': 'mediumSquare149',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-mediumSquare149.jpg',
#     'height': 149,
#     'width': 149,
#     'legacy': {},
#     'subType': 'mediumSquare149',
#     'crop_name': 'mediumSquare149'},
#    {'rank': 0,
#     'subtype': 'mediumSquareAt3X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-mediumSquareAt3X.jpg',
#     'height': 1800,
#     'width': 1800,
#     'legacy': {},
#     'subType': 'mediumSquareAt3X',
#     'crop_name': 'mediumSquareAt3X'},
#    {'rank': 0,
#     'subtype': 'sfSpan',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-sfSpan.jpg',
#     'height': 263,
#     'width': 395,
#     'legacy': {},
#     'subType': 'sfSpan',
#     'crop_name': 'sfSpan'},
#    {'rank': 0,
#     'subtype': 'largeHorizontal375',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-largeHorizontal375.jpg',
#     'height': 250,
#     'width': 375,
#     'legacy': {},
#     'subType': 'largeHorizontal375',
#     'crop_name': 'largeHorizontal375'},
#    {'rank': 0,
#     'subtype': 'largeHorizontalJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-largeHorizontalJumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'largeHorizontalJumbo',
#     'crop_name': 'largeHorizontalJumbo'},
#    {'rank': 0,
#     'subtype': 'horizontalMediumAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-horizontalMediumAt2X.jpg',
#     'height': 1670,
#     'width': 2504,
#     'legacy': {},
#     'subType': 'horizontalMediumAt2X',
#     'crop_name': 'horizontalMediumAt2X'},
#    {'rank': 0,
#     'subtype': 'hpLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-hpLarge.jpg',
#     'height': 287,
#     'width': 511,
#     'legacy': {},
#     'subType': 'hpLarge',
#     'crop_name': 'hpLarge'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen573',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-largeWidescreen573.jpg',
#     'height': 322,
#     'width': 573,
#     'legacy': {},
#     'subType': 'largeWidescreen573',
#     'crop_name': 'largeWidescreen573'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-largeWidescreen1050.jpg',
#     'height': 590,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'largeWidescreen1050',
#     'crop_name': 'largeWidescreen1050'},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'widewidth': 190,
#      'wideheight': 126,
#      'wide': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-thumbWide.jpg'},
#     'subType': 'wide',
#     'crop_name': 'thumbWide'},
#    {'rank': 0,
#     'subtype': 'videoThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoThumb.jpg',
#     'height': 50,
#     'width': 75,
#     'legacy': {},
#     'subType': 'videoThumb',
#     'crop_name': 'videoThumb'},
#    {'rank': 0,
#     'subtype': 'videoLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoLarge.jpg',
#     'height': 507,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoLarge',
#     'crop_name': 'videoLarge'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo210',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-mediumThreeByTwo210.jpg',
#     'height': 140,
#     'width': 210,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo210',
#     'crop_name': 'mediumThreeByTwo210'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-mediumThreeByTwo225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo225',
#     'crop_name': 'mediumThreeByTwo225'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo440',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-mediumThreeByTwo440.jpg',
#     'height': 293,
#     'width': 440,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo440',
#     'crop_name': 'mediumThreeByTwo440'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-mediumThreeByTwo252.jpg',
#     'height': 168,
#     'width': 252,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo252',
#     'crop_name': 'mediumThreeByTwo252'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo378',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-mediumThreeByTwo378.jpg',
#     'height': 252,
#     'width': 378,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo378',
#     'crop_name': 'mediumThreeByTwo378'},
#    {'rank': 0,
#     'subtype': 'threeByTwoLargeAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-threeByTwoLargeAt2X.jpg',
#     'height': 1669,
#     'width': 2504,
#     'legacy': {},
#     'subType': 'threeByTwoLargeAt2X',
#     'crop_name': 'threeByTwoLargeAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoMediumAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-threeByTwoMediumAt2X.jpg',
#     'height': 1000,
#     'width': 1500,
#     'legacy': {},
#     'subType': 'threeByTwoMediumAt2X',
#     'crop_name': 'threeByTwoMediumAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoSmallAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-threeByTwoSmallAt2X.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'threeByTwoSmallAt2X',
#     'crop_name': 'threeByTwoSmallAt2X'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-articleInline.jpg',
#     'height': 285,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-hpSmall.jpg',
#     'height': 245,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-blogSmallInline.jpg',
#     'height': 227,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-mediumFlexible177.jpg',
#     'height': 266,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoSixteenByNine540.jpg',
#     'height': 304,
#     'width': 540,
#     'legacy': {},
#     'subType': 'videoSixteenByNine540',
#     'crop_name': 'videoSixteenByNine540'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoSixteenByNine495.jpg',
#     'height': 278,
#     'width': 495,
#     'legacy': {},
#     'subType': 'videoSixteenByNine495',
#     'crop_name': 'videoSixteenByNine495'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine390',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoSixteenByNine390.jpg',
#     'height': 219,
#     'width': 390,
#     'legacy': {},
#     'subType': 'videoSixteenByNine390',
#     'crop_name': 'videoSixteenByNine390'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoSixteenByNine1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'videoSixteenByNine1050',
#     'crop_name': 'videoSixteenByNine1050'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoSixteenByNine480.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'videoSixteenByNine480',
#     'crop_name': 'videoSixteenByNine480'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine310',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoSixteenByNine310.jpg',
#     'height': 174,
#     'width': 310,
#     'legacy': {},
#     'subType': 'videoSixteenByNine310',
#     'crop_name': 'videoSixteenByNine310'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoSixteenByNine225.jpg',
#     'height': 126,
#     'width': 225,
#     'legacy': {},
#     'subType': 'videoSixteenByNine225',
#     'crop_name': 'videoSixteenByNine225'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine96',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoSixteenByNine96.jpg',
#     'height': 54,
#     'width': 96,
#     'legacy': {},
#     'subType': 'videoSixteenByNine96',
#     'crop_name': 'videoSixteenByNine96'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoSixteenByNine768.jpg',
#     'height': 432,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoSixteenByNine768',
#     'crop_name': 'videoSixteenByNine768'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine150',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoSixteenByNine150.jpg',
#     'height': 84,
#     'width': 150,
#     'legacy': {},
#     'subType': 'videoSixteenByNine150',
#     'crop_name': 'videoSixteenByNine150'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNineJumbo1600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoSixteenByNineJumbo1600.jpg',
#     'height': 900,
#     'width': 1600,
#     'legacy': {},
#     'subType': 'videoSixteenByNineJumbo1600',
#     'crop_name': 'videoSixteenByNineJumbo1600'},
#    {'rank': 0,
#     'subtype': 'miniMoth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-miniMoth.jpg',
#     'height': 70,
#     'width': 151,
#     'legacy': {},
#     'subType': 'miniMoth',
#     'crop_name': 'miniMoth'},
#    {'rank': 0,
#     'subtype': 'windowsTile336H',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-windowsTile336H.jpg',
#     'height': 336,
#     'width': 694,
#     'legacy': {},
#     'subType': 'windowsTile336H',
#     'crop_name': 'windowsTile336H'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven1305',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-videoFifteenBySeven1305.jpg',
#     'height': 609,
#     'width': 1305,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven1305',
#     'crop_name': 'videoFifteenBySeven1305'},
#    {'rank': 0,
#     'subtype': 'facebookJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-facebookJumbo.jpg',
#     'height': 550,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'facebookJumbo',
#     'crop_name': 'facebookJumbo'},
#    {'rank': 0,
#     'subtype': 'watch308',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-watch308.jpg',
#     'height': 348,
#     'width': 312,
#     'legacy': {},
#     'subType': 'watch308',
#     'crop_name': 'watch308'},
#    {'rank': 0,
#     'subtype': 'watch268',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-watch268.jpg',
#     'height': 303,
#     'width': 272,
#     'legacy': {},
#     'subType': 'watch268',
#     'crop_name': 'watch268'},
#    {'rank': 0,
#     'subtype': 'verticalTwoByThree735',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/merlin_174156807_ce2cfe53-5bf6-444d-9db1-fc92c5d0c612-verticalTwoByThree735.jpg',
#     'height': 1103,
#     'width': 735,
#     'legacy': {},
#     'subType': 'verticalTwoByThree735',
#     'crop_name': 'verticalTwoByThree735'},
#    {'rank': 0,
#     'subtype': 'mobileMasterAt3x',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/01/business/31economy-briefing-strauss-vance-2/31economy-briefing-strauss-vance-2-mobileMasterAt3x.jpg',
#     'height': 2700,
#     'width': 1800,
#     'legacy': {},
#     'subType': 'mobileMasterAt3x',
#     'crop_name': 'mobileMasterAt3x'}],
#   'headline': {'main': 'Two top New York public prosecutors rejoin private practice.',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'After Trump-Era Turbulence, 2 Top New York Public Prosecutors Go Back to Private Practice',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Appointments and Executive Changes',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'United States Politics and Government',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'United States Attorneys',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'persons',
#     'value': 'Strauss, Audrey (Attorney)',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Vance, Cyrus R Jr', 'rank': 5, 'major': 'N'}],
#   'pub_date': '2022-01-31T15:41:16+0000',
#   'document_type': 'article',
#   'news_desk': 'Business',
#   'section_name': 'Business Day',
#   'byline': {'original': 'By Benjamin Weiser and Ephrat Livni',
#    'person': [{'firstname': 'Benjamin',
#      'middlename': None,
#      'lastname': 'Weiser',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1},
#     {'firstname': 'Ephrat',
#      'middlename': None,
#      'lastname': 'Livni',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 2}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/b2f45307-18f3-5671-9316-803b35971b08',
#   'word_count': 667,
#   'uri': 'nyt://article/b2f45307-18f3-5671-9316-803b35971b08'},
#  {'abstract': 'In response to criticism of Joe Rogan’s podcast, the streaming service says it’s a platform, not a media company. That’s a familiar refrain.',
#   'web_url': 'https://www.nytimes.com/2022/01/31/business/dealbook/spotify-rogan-ek.html',
#   'snippet': 'In response to criticism of Joe Rogan’s podcast, the streaming service says it’s a platform, not a media company. That’s a familiar refrain.',
#   'lead_paragraph': 'Spotify has faced increasing pressure as high-profile artists have pulled their songs from the streaming platform to protest its hosting of Joe Rogan’s popular podcast, which has been criticized for spreading misinformation about the coronavirus. Over the weekend, Spotify’s C.E.O., Daniel Ek, said that the service would add a “content advisory” to some podcasts and Rogan pledged to “balance things out.”',
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlarge': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-articleLarge.jpg',
#      'xlargewidth': 600,
#      'xlargeheight': 400},
#     'subType': 'xlarge',
#     'crop_name': 'articleLarge'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-popup.jpg',
#     'height': 433,
#     'width': 650,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'blog480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-blog480.jpg',
#     'height': 320,
#     'width': 480,
#     'legacy': {},
#     'subType': 'blog480',
#     'crop_name': 'blog480'},
#    {'rank': 0,
#     'subtype': 'blog533',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-blog533.jpg',
#     'height': 355,
#     'width': 533,
#     'legacy': {},
#     'subType': 'blog533',
#     'crop_name': 'blog533'},
#    {'rank': 0,
#     'subtype': 'blog427',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-blog427.jpg',
#     'height': 285,
#     'width': 427,
#     'legacy': {},
#     'subType': 'blog427',
#     'crop_name': 'blog427'},
#    {'rank': 0,
#     'subtype': 'tmagSF',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-tmagSF.jpg',
#     'height': 241,
#     'width': 362,
#     'legacy': {},
#     'subType': 'tmagSF',
#     'crop_name': 'tmagSF'},
#    {'rank': 0,
#     'subtype': 'tmagArticle',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-tmagArticle.jpg',
#     'height': 395,
#     'width': 592,
#     'legacy': {},
#     'subType': 'tmagArticle',
#     'crop_name': 'tmagArticle'},
#    {'rank': 0,
#     'subtype': 'slide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-slide.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'slide',
#     'crop_name': 'slide'},
#    {'rank': 0,
#     'subtype': 'jumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-jumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'jumbo',
#     'crop_name': 'jumbo'},
#    {'rank': 0,
#     'subtype': 'superJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-superJumbo.jpg',
#     'height': 1365,
#     'width': 2048,
#     'legacy': {},
#     'subType': 'superJumbo',
#     'crop_name': 'superJumbo'},
#    {'rank': 0,
#     'subtype': 'blog225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-blog225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'blog225',
#     'crop_name': 'blog225'},
#    {'rank': 0,
#     'subtype': 'master1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-master1050.jpg',
#     'height': 700,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'master1050',
#     'crop_name': 'master1050'},
#    {'rank': 0,
#     'subtype': 'master675',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-master675.jpg',
#     'height': 450,
#     'width': 675,
#     'legacy': {},
#     'subType': 'master675',
#     'crop_name': 'master675'},
#    {'rank': 0,
#     'subtype': 'master495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-master495.jpg',
#     'height': 330,
#     'width': 495,
#     'legacy': {},
#     'subType': 'master495',
#     'crop_name': 'master495'},
#    {'rank': 0,
#     'subtype': 'master180',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-master180.jpg',
#     'height': 120,
#     'width': 180,
#     'legacy': {},
#     'subType': 'master180',
#     'crop_name': 'master180'},
#    {'rank': 0,
#     'subtype': 'master315',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-master315.jpg',
#     'height': 210,
#     'width': 315,
#     'legacy': {},
#     'subType': 'master315',
#     'crop_name': 'master315'},
#    {'rank': 0,
#     'subtype': 'master768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-master768.jpg',
#     'height': 512,
#     'width': 768,
#     'legacy': {},
#     'subType': 'master768',
#     'crop_name': 'master768'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnail': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-thumbStandard.jpg',
#      'thumbnailwidth': 75,
#      'thumbnailheight': 75},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'},
#    {'rank': 0,
#     'subtype': 'blogSmallThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-blogSmallThumb.jpg',
#     'height': 50,
#     'width': 50,
#     'legacy': {},
#     'subType': 'blogSmallThumb',
#     'crop_name': 'blogSmallThumb'},
#    {'rank': 0,
#     'subtype': 'thumbLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-thumbLarge.jpg',
#     'height': 150,
#     'width': 150,
#     'legacy': {},
#     'subType': 'thumbLarge',
#     'crop_name': 'thumbLarge'},
#    {'rank': 0,
#     'subtype': 'smallSquare168',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-smallSquare168.jpg',
#     'height': 168,
#     'width': 168,
#     'legacy': {},
#     'subType': 'smallSquare168',
#     'crop_name': 'smallSquare168'},
#    {'rank': 0,
#     'subtype': 'smallSquare252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-smallSquare252.jpg',
#     'height': 252,
#     'width': 252,
#     'legacy': {},
#     'subType': 'smallSquare252',
#     'crop_name': 'smallSquare252'},
#    {'rank': 0,
#     'subtype': 'square320',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-square320.jpg',
#     'height': 320,
#     'width': 320,
#     'legacy': {},
#     'subType': 'square320',
#     'crop_name': 'square320'},
#    {'rank': 0,
#     'subtype': 'moth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-moth.jpg',
#     'height': 151,
#     'width': 151,
#     'legacy': {},
#     'subType': 'moth',
#     'crop_name': 'moth'},
#    {'rank': 0,
#     'subtype': 'filmstrip',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-filmstrip.jpg',
#     'height': 190,
#     'width': 190,
#     'legacy': {},
#     'subType': 'filmstrip',
#     'crop_name': 'filmstrip'},
#    {'rank': 0,
#     'subtype': 'square640',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-square640.jpg',
#     'height': 640,
#     'width': 640,
#     'legacy': {},
#     'subType': 'square640',
#     'crop_name': 'square640'},
#    {'rank': 0,
#     'subtype': 'mediumSquare149',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-mediumSquare149.jpg',
#     'height': 149,
#     'width': 149,
#     'legacy': {},
#     'subType': 'mediumSquare149',
#     'crop_name': 'mediumSquare149'},
#    {'rank': 0,
#     'subtype': 'mediumSquareAt3X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-mediumSquareAt3X.jpg',
#     'height': 1800,
#     'width': 1800,
#     'legacy': {},
#     'subType': 'mediumSquareAt3X',
#     'crop_name': 'mediumSquareAt3X'},
#    {'rank': 0,
#     'subtype': 'sfSpan',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-sfSpan.jpg',
#     'height': 263,
#     'width': 395,
#     'legacy': {},
#     'subType': 'sfSpan',
#     'crop_name': 'sfSpan'},
#    {'rank': 0,
#     'subtype': 'largeHorizontal375',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-largeHorizontal375.jpg',
#     'height': 250,
#     'width': 375,
#     'legacy': {},
#     'subType': 'largeHorizontal375',
#     'crop_name': 'largeHorizontal375'},
#    {'rank': 0,
#     'subtype': 'largeHorizontalJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-largeHorizontalJumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'largeHorizontalJumbo',
#     'crop_name': 'largeHorizontalJumbo'},
#    {'rank': 0,
#     'subtype': 'horizontalMediumAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-horizontalMediumAt2X.jpg',
#     'height': 2000,
#     'width': 3000,
#     'legacy': {},
#     'subType': 'horizontalMediumAt2X',
#     'crop_name': 'horizontalMediumAt2X'},
#    {'rank': 0,
#     'subtype': 'hpLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-hpLarge.jpg',
#     'height': 288,
#     'width': 511,
#     'legacy': {},
#     'subType': 'hpLarge',
#     'crop_name': 'hpLarge'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen573',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-largeWidescreen573.jpg',
#     'height': 322,
#     'width': 573,
#     'legacy': {},
#     'subType': 'largeWidescreen573',
#     'crop_name': 'largeWidescreen573'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-largeWidescreen1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'largeWidescreen1050',
#     'crop_name': 'largeWidescreen1050'},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'widewidth': 190,
#      'wideheight': 126,
#      'wide': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-thumbWide.jpg'},
#     'subType': 'wide',
#     'crop_name': 'thumbWide'},
#    {'rank': 0,
#     'subtype': 'videoThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-videoThumb.jpg',
#     'height': 50,
#     'width': 75,
#     'legacy': {},
#     'subType': 'videoThumb',
#     'crop_name': 'videoThumb'},
#    {'rank': 0,
#     'subtype': 'videoLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-videoLarge.jpg',
#     'height': 507,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoLarge',
#     'crop_name': 'videoLarge'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo210',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-mediumThreeByTwo210.jpg',
#     'height': 140,
#     'width': 210,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo210',
#     'crop_name': 'mediumThreeByTwo210'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-mediumThreeByTwo225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo225',
#     'crop_name': 'mediumThreeByTwo225'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo440',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-mediumThreeByTwo440.jpg',
#     'height': 293,
#     'width': 440,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo440',
#     'crop_name': 'mediumThreeByTwo440'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-mediumThreeByTwo252.jpg',
#     'height': 168,
#     'width': 252,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo252',
#     'crop_name': 'mediumThreeByTwo252'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo378',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-mediumThreeByTwo378.jpg',
#     'height': 252,
#     'width': 378,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo378',
#     'crop_name': 'mediumThreeByTwo378'},
#    {'rank': 0,
#     'subtype': 'threeByTwoLargeAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-threeByTwoLargeAt2X.jpg',
#     'height': 2000,
#     'width': 3000,
#     'legacy': {},
#     'subType': 'threeByTwoLargeAt2X',
#     'crop_name': 'threeByTwoLargeAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoMediumAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-threeByTwoMediumAt2X.jpg',
#     'height': 1000,
#     'width': 1500,
#     'legacy': {},
#     'subType': 'threeByTwoMediumAt2X',
#     'crop_name': 'threeByTwoMediumAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoSmallAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-threeByTwoSmallAt2X.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'threeByTwoSmallAt2X',
#     'crop_name': 'threeByTwoSmallAt2X'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-articleInline.jpg',
#     'height': 127,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-hpSmall.jpg',
#     'height': 109,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-blogSmallInline.jpg',
#     'height': 101,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-mediumFlexible177.jpg',
#     'height': 118,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/31/multimedia/31db-newsletter-rogan/31db-newsletter-rogan-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
# ...
#     'legacy': {},
#     'subType': 'videoThumb',
#     'crop_name': 'videoThumb'},
#    {'rank': 0,
#     'subtype': 'videoLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoLarge.jpg',
#     'height': 507,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoLarge',
#     'crop_name': 'videoLarge'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo210',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-mediumThreeByTwo210.jpg',
#     'height': 140,
#     'width': 210,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo210',
#     'crop_name': 'mediumThreeByTwo210'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-mediumThreeByTwo225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo225',
#     'crop_name': 'mediumThreeByTwo225'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo440',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-mediumThreeByTwo440.jpg',
#     'height': 293,
#     'width': 440,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo440',
#     'crop_name': 'mediumThreeByTwo440'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-mediumThreeByTwo252.jpg',
#     'height': 168,
#     'width': 252,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo252',
#     'crop_name': 'mediumThreeByTwo252'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo378',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-mediumThreeByTwo378.jpg',
#     'height': 252,
#     'width': 378,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo378',
#     'crop_name': 'mediumThreeByTwo378'},
#    {'rank': 0,
#     'subtype': 'threeByTwoLargeAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-threeByTwoLargeAt2X.jpg',
#     'height': 2333,
#     'width': 3500,
#     'legacy': {},
#     'subType': 'threeByTwoLargeAt2X',
#     'crop_name': 'threeByTwoLargeAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoMediumAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-threeByTwoMediumAt2X.jpg',
#     'height': 1000,
#     'width': 1500,
#     'legacy': {},
#     'subType': 'threeByTwoMediumAt2X',
#     'crop_name': 'threeByTwoMediumAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoSmallAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-threeByTwoSmallAt2X.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'threeByTwoSmallAt2X',
#     'crop_name': 'threeByTwoSmallAt2X'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-articleInline.jpg',
#     'height': 127,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-hpSmall.jpg',
#     'height': 109,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-blogSmallInline.jpg',
#     'height': 101,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-mediumFlexible177.jpg',
#     'height': 118,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoSixteenByNine540.jpg',
#     'height': 304,
#     'width': 540,
#     'legacy': {},
#     'subType': 'videoSixteenByNine540',
#     'crop_name': 'videoSixteenByNine540'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoSixteenByNine495.jpg',
#     'height': 278,
#     'width': 495,
#     'legacy': {},
#     'subType': 'videoSixteenByNine495',
#     'crop_name': 'videoSixteenByNine495'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine390',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoSixteenByNine390.jpg',
#     'height': 219,
#     'width': 390,
#     'legacy': {},
#     'subType': 'videoSixteenByNine390',
#     'crop_name': 'videoSixteenByNine390'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoSixteenByNine1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'videoSixteenByNine1050',
#     'crop_name': 'videoSixteenByNine1050'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoSixteenByNine480.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'videoSixteenByNine480',
#     'crop_name': 'videoSixteenByNine480'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine310',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoSixteenByNine310.jpg',
#     'height': 174,
#     'width': 310,
#     'legacy': {},
#     'subType': 'videoSixteenByNine310',
#     'crop_name': 'videoSixteenByNine310'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoSixteenByNine225.jpg',
#     'height': 126,
#     'width': 225,
#     'legacy': {},
#     'subType': 'videoSixteenByNine225',
#     'crop_name': 'videoSixteenByNine225'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine96',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoSixteenByNine96.jpg',
#     'height': 54,
#     'width': 96,
#     'legacy': {},
#     'subType': 'videoSixteenByNine96',
#     'crop_name': 'videoSixteenByNine96'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine3000',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoSixteenByNine3000.jpg',
#     'height': 1688,
#     'width': 3000,
#     'legacy': {},
#     'subType': 'videoSixteenByNine3000',
#     'crop_name': 'videoSixteenByNine3000'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoSixteenByNine768.jpg',
#     'height': 432,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoSixteenByNine768',
#     'crop_name': 'videoSixteenByNine768'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine150',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoSixteenByNine150.jpg',
#     'height': 84,
#     'width': 150,
#     'legacy': {},
#     'subType': 'videoSixteenByNine150',
#     'crop_name': 'videoSixteenByNine150'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNineJumbo1600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoSixteenByNineJumbo1600.jpg',
#     'height': 900,
#     'width': 1600,
#     'legacy': {},
#     'subType': 'videoSixteenByNineJumbo1600',
#     'crop_name': 'videoSixteenByNineJumbo1600'},
#    {'rank': 0,
#     'subtype': 'miniMoth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-miniMoth.jpg',
#     'height': 70,
#     'width': 151,
#     'legacy': {},
#     'subType': 'miniMoth',
#     'crop_name': 'miniMoth'},
#    {'rank': 0,
#     'subtype': 'windowsTile336H',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-windowsTile336H.jpg',
#     'height': 336,
#     'width': 694,
#     'legacy': {},
#     'subType': 'windowsTile336H',
#     'crop_name': 'windowsTile336H'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven1305',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoFifteenBySeven1305.jpg',
#     'height': 609,
#     'width': 1305,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven1305',
#     'crop_name': 'videoFifteenBySeven1305'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven2610',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-videoFifteenBySeven2610.jpg',
#     'height': 1218,
#     'width': 2610,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven2610',
#     'crop_name': 'videoFifteenBySeven2610'},
#    {'rank': 0,
#     'subtype': 'facebookJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-facebookJumbo.jpg',
#     'height': 549,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'facebookJumbo',
#     'crop_name': 'facebookJumbo'},
#    {'rank': 0,
#     'subtype': 'watch308',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-watch308.jpg',
#     'height': 348,
#     'width': 312,
#     'legacy': {},
#     'subType': 'watch308',
#     'crop_name': 'watch308'},
#    {'rank': 0,
#     'subtype': 'watch268',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-watch268.jpg',
#     'height': 303,
#     'width': 272,
#     'legacy': {},
#     'subType': 'watch268',
#     'crop_name': 'watch268'},
#    {'rank': 0,
#     'subtype': 'verticalTwoByThree735',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-verticalTwoByThree735.jpg',
#     'height': 1103,
#     'width': 735,
#     'legacy': {},
#     'subType': 'verticalTwoByThree735',
#     'crop_name': 'verticalTwoByThree735'},
#    {'rank': 0,
#     'subtype': 'mobileMasterAt3x',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/01/14/us/politics/14dc-voting-1/merlin_200213256_2b764925-de30-422c-b150-545a7997e819-mobileMasterAt3x.jpg',
#     'height': 1201,
#     'width': 1800,
#     'legacy': {},
#     'subType': 'mobileMasterAt3x',
#     'crop_name': 'mobileMasterAt3x'}],
#   'headline': {'main': 'Democrats Face a Dilemma on Voting: Compromise or Keep Pressing?',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'For Democrats, Hard Decisions On Voting Push',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Voting Rights, Registration and Requirements',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Democratic Party',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Republican Party',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'organizations', 'value': 'Senate', 'rank': 4, 'major': 'N'},
#    {'name': 'organizations',
#     'value': 'House of Representatives',
#     'rank': 5,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Filibusters and Debate Curbs',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Law and Legislation',
#     'rank': 7,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'United States Politics and Government',
#     'rank': 8,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Presidential Election of 2020',
#     'rank': 9,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'States (US)', 'rank': 10, 'major': 'N'}],
#   'pub_date': '2022-01-15T00:16:21+0000',
#   'document_type': 'article',
#   'news_desk': 'Washington',
#   'section_name': 'U.S.',
#   'subsection_name': 'Politics',
#   'byline': {'original': 'By Jonathan Weisman',
#    'person': [{'firstname': 'Jonathan',
#      'middlename': None,
#      'lastname': 'Weisman',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/092b7c77-b6b7-58ba-920d-29d39848f7fa',
#   'word_count': 1512,
#   'uri': 'nyt://article/092b7c77-b6b7-58ba-920d-29d39848f7fa'}]

# %%
# BONUS: How would we get 30 results? 
# HINT: Look up the page query param
#param = {"page=3"}
# Empty list for articles
articles_list = []

# loop through pages 0-2
for page in range(0, 3):
    query_url = f"{url}api-key={nytapi_key}&q={query}&begin_date={begin_date}&end_date={end_date}&page={page}"
    #print(query_url)
    response = requests.get(query_url).json()
    #print(response)
    # Add a one second interval between queries to stay within API query limits
    time.sleep(1)
    # loop through the response and append each article to the list
    #run query

    # get article from query
    x = response['response']['docs']
    
    # add an article
    for article in x:
        #print(article)
        articles_list.append(article)
        
#print(articles_list)
articles_list_df = pd.DataFrame(articles_list)
articles_list_df
# Out:
#                                              abstract  \
# 0   Audrey Strauss is returning to the law firm Fr...
# 1   In response to criticism of Joe Rogan’s podcas...
# 2   The announcement came months after the U.S. go...
# 3   Parag Agrawal, the new chief executive, fired ...
# 4   Moscow said the ransomware group REvil “ceased...
# 5   Android-powered devices carrying the BlackBerr...
# 6   Researchers said the app, which will store sen...
# 7   There’s virtually no aspect of our lives that ...
# 8   The nominees would bring more diverse leadersh...
# 9   With their broad voting rights push nearing a ...
# 10  Cloud computing is slowly changing how Wall St...
# 11  The crackdown is killing the entrepreneurial d...
# 12  From a nondescript office building, a few doze...
# 13  Andrew was sued in New York by Virginia Giuffr...
# 14  Wild swings in stocks haven’t shown up in othe...
# 15  Following last week’s Supreme Court ruling, th...
# 16  A Times investigation reveals how Israel reape...
#
#                                               web_url  \
# 0   https://www.nytimes.com/2022/01/31/business/au...
# 1   https://www.nytimes.com/2022/01/31/business/de...
# 2   https://www.nytimes.com/2022/01/12/world/ameri...
# 3   https://www.nytimes.com/2022/01/21/technology/...
# 4   https://www.nytimes.com/2022/01/14/world/europ...
# 5   https://www.nytimes.com/2022/01/03/technology/...
# 6   https://www.nytimes.com/2022/01/18/technology/...
# 7   https://www.nytimes.com/2022/01/26/magazine/co...
# 8   https://www.nytimes.com/2022/01/13/business/ec...
# 9   https://www.nytimes.com/2022/01/14/us/politics...
# 10  https://www.nytimes.com/2022/01/03/business/wa...
# 11  https://www.nytimes.com/2022/01/05/technology/...
# 12  https://www.nytimes.com/2022/01/04/us/politics...
# 13  https://www.nytimes.com/2022/01/13/nyregion/pr...
# 14  https://www.nytimes.com/2022/01/26/business/de...
# 15  https://www.nytimes.com/2022/01/24/us/politics...
# 16  https://www.nytimes.com/2022/01/28/magazine/ns...
#
#                                               snippet  \
# 0   Audrey Strauss is returning to the law firm Fr...
# 1   In response to criticism of Joe Rogan’s podcas...
# 2   The announcement came months after the U.S. go...
# 3   Parag Agrawal, the new chief executive, fired ...
# 4   Moscow said the ransomware group REvil “ceased...
# 5   Android-powered devices carrying the BlackBerr...
# 6   Researchers said the app, which will store sen...
# 7   There’s virtually no aspect of our lives that ...
# 8   The nominees would bring more diverse leadersh...
# 9   With their broad voting rights push nearing a ...
# 10  Cloud computing is slowly changing how Wall St...
# 11  The crackdown is killing the entrepreneurial d...
# 12  From a nondescript office building, a few doze...
# 13  Andrew was sued in New York by Virginia Giuffr...
# 14  Wild swings in stocks haven’t shown up in othe...
# 15  Following last week’s Supreme Court ruling, th...
# 16  A Times investigation reveals how Israel reape...
#
#                                        lead_paragraph print_section  \
# 0   Audrey Strauss and Cyrus R. Vance Jr., two pro...             B
# 1   Spotify has faced increasing pressure as high-...           NaN
# 2   El Salvador’s leading news outlet, El Faro, sa...             A
# 3   SAN FRANCISCO — Twitter shook up the top ranks...           NaN
# 4   MOSCOW — Russia’s main security agency said on...             A
# 5   To legions of executives, journalists and poli...             B
# 6   The mandatory smartphone app that athletes wil...             B
# 7   At some point, hopefully soon, infections from...            MM
# 8   President Biden plans to nominate three new Fe...             B
# 9   WASHINGTON — With their drive to secure far-re...             A
# 10  Michael W. Lucas made big plans to take a trip...             B
# 11  Like many ambitious young Chinese, Zhao Junfen...             B
# 12  Follow our live updates on the Jan. 6 Capitol ...             A
# 13  Good morning. It’s Thursday. We’ll look at a d...           NaN
# 14  Stock markets took investors on another wild r...           NaN
# 15  The National Archives has turned over to the H...             A
# 16  In June 2019, three Israeli computer engineers...            MM
#
#    print_page              source  \
# 0           6  The New York Times
# 1         NaN  The New York Times
# 2          10  The New York Times
# 3         NaN  The New York Times
# 4           6  The New York Times
# 5           3  The New York Times
# 6           1  The New York Times
# 7          16  The New York Times
# 8           3  The New York Times
# 9           1  The New York Times
# 10          1  The New York Times
# 11          1  The New York Times
# 12         16  The New York Times
# 13        NaN  The New York Times
# 14        NaN  The New York Times
# 15         17  The New York Times
# 16         36  The New York Times
#
#                                            multimedia  \
# 0   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 5   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 6   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 7   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 8   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 9   [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 10  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 11  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 12  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 13  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 14  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 15  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 16  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                              headline  \
# 0   {'main': 'Two top New York public prosecutors ...
# 1   {'main': 'Does Spotify Have an Identity Crisis...
# 2   {'main': 'Journalists in El Salvador Targeted ...
# 3   {'main': 'Twitter shakes up its security team....
# 4   {'main': 'Russia Says It Shut Down Notorious H...
# 5   {'main': 'BlackBerry Ends Service on Its Once-...
# 6   {'main': 'Security Flaws Seen in China’s Manda...
# 7   {'main': 'Counting Covid-19 Cases Doesn’t Capt...
# 8   {'main': 'Biden Will Nominate Three New Fed Of...
# 9   {'main': 'Democrats Face a Dilemma on Voting: ...
# 10  {'main': 'Banks Tiptoe Toward Their Cloud-Base...
# 11  {'main': 'As Beijing Takes Control, Chinese Te...
# 12  {'main': 'In the Capitol’s Shadow, the Jan. 6 ...
# 13  {'main': 'Prince Andrew Can’t Avoid His Day in...
# 14  {'main': 'In Some Markets, Cooler Heads Are Pr...
# 15  {'main': 'What the Trump Documents Might Tell ...
# 16  {'main': 'The Battle for the World’s Most Powe...
#
#                                              keywords  \
# 0   [{'name': 'subject', 'value': 'Appointments an...
# 1   [{'name': 'persons', 'value': 'Vance, Cyrus R ...
# 2   [{'name': 'subject', 'value': 'Surveillance of...
# 3   [{'name': 'subject', 'value': 'Social Media', ...
# 4   [{'name': 'organizations', 'value': 'REvil (Ha...
# 5   [{'name': 'subject', 'value': 'Wireless Commun...
# 6   [{'name': 'subject', 'value': 'Computer Securi...
# 7   [{'name': 'subject', 'value': 'Disease Rates',...
# 8   [{'name': 'organizations', 'value': 'Federal R...
# 9   [{'name': 'subject', 'value': 'Voting Rights, ...
# 10  [{'name': 'subject', 'value': 'Banking and Fin...
# 11  [{'name': 'glocations', 'value': 'China', 'ran...
# 12  [{'name': 'subject', 'value': 'Storming of the...
# 13  [{'name': 'glocations', 'value': 'New York Cit...
# 14  [{'name': 'subject', 'value': 'International T...
# 15  [{'name': 'subject', 'value': 'Presidential El...
# 16  [{'name': 'organizations', 'value': 'NSO Group...
#
#                     pub_date document_type   news_desk  section_name  \
# 0   2022-01-31T15:41:16+0000       article    Business  Business Day
# 1   2022-01-31T13:16:27+0000       article    Business  Business Day
# 2   2022-01-13T00:01:17+0000       article     Foreign         World
# 3   2022-01-21T06:33:15+0000       article    Business    Technology
# 4   2022-01-15T00:09:26+0000       article     Foreign         World
# 5   2022-01-03T22:44:31+0000       article     Express    Technology
# 6   2022-01-18T11:00:08+0000       article    Business    Technology
# 7   2022-01-26T10:00:12+0000       article    Magazine      Magazine
# 8   2022-01-14T01:39:11+0000       article    Business  Business Day
# 9   2022-01-15T00:16:21+0000       article  Washington          U.S.
# 10  2022-01-03T08:00:10+0000       article    Business  Business Day
# 11  2022-01-05T10:00:28+0000       article    Business    Technology
# 12  2022-01-04T10:00:12+0000       article  Washington          U.S.
# 13  2022-01-13T08:25:13+0000       article       Metro      New York
# 14  2022-01-26T12:42:51+0000       article    Business  Business Day
# 15  2022-01-25T00:20:49+0000       article  Washington          U.S.
# 16  2022-01-28T10:00:23+0000       article    Magazine      Magazine
#
#                                                byline type_of_material  \
# 0   {'original': 'By Benjamin Weiser and Ephrat Li...             News
# 1   {'original': 'By Andrew Ross Sorkin, Jason Kar...             News
# 2   {'original': 'By Maria Abi-Habib', 'person': [...             News
# 3   {'original': 'By Mike Isaac and Kate Conger', ...             News
# 4   {'original': 'By Ivan Nechepurenko', 'person':...             News
# 5   {'original': 'By Neil Vigdor', 'person': [{'fi...             News
# 6   {'original': 'By Paul Mozur and Cade Metz', 'p...             News
# 7   {'original': 'By Kim Tingley', 'person': [{'fi...             News
# 8   {'original': 'By Jeanna Smialek', 'person': [{...             News
# 9   {'original': 'By Jonathan Weisman', 'person': ...             News
# 10  {'original': 'By Lananh Nguyen', 'person': [{'...             News
# 11  {'original': 'By Li Yuan', 'person': [{'firstn...             News
# 12  {'original': 'By Luke Broadwater and Alan Feue...             News
# 13  {'original': 'By James Barron', 'person': [{'f...         briefing
# 14  {'original': 'By Andrew Ross Sorkin, Jason Kar...             News
# 15  {'original': 'By Luke Broadwater, Alan Feuer, ...             News
# 16  {'original': 'By Ronen Bergman and Mark Mazzet...             News
#
#                                                   _id  word_count  \
# 0   nyt://article/b2f45307-18f3-5671-9316-803b3597...         667
# 1   nyt://article/6570bc21-22c3-531a-b313-2eb670a4...        1794
# 2   nyt://article/e60c8d0d-c32c-5449-922d-9c664078...         733
# 3   nyt://article/3ec05366-9433-55ec-9c2c-d88b4cf0...         355
# 4   nyt://article/bb4473f7-e3df-532d-8847-9193187f...         837
# 5   nyt://article/dd7a3c99-fc59-57b3-8de4-cac183c3...         880
# 6   nyt://article/00281bca-9d5d-5d22-9d2c-7aed99b9...         973
# 7   nyt://article/ebd9f6be-d8a6-53c6-9750-e022d7fa...        1342
# 8   nyt://article/0d4ce260-1a49-590e-9af3-5b507a08...        1288
# 9   nyt://article/092b7c77-b6b7-58ba-920d-29d39848...        1512
# 10  nyt://article/6a4fbfe5-0434-56a9-a389-9afc8c34...        1413
# 11  nyt://article/afd01f3f-4721-5ba1-83ad-8085f4dc...        1359
# 12  nyt://article/5d87ba91-e910-5fbd-9e70-483282a7...        1604
# 13  nyt://article/e3da27de-a688-55c0-b7d4-797ac1b7...        1493
# 14  nyt://article/c7a1d75d-c769-5651-9cb4-d3f66229...        1818
# 15  nyt://article/2f7c81b2-5ba9-5b5b-b5b5-112f7a4f...        1870
# 16  nyt://article/2aeab53d-67d8-5a54-85b0-fd04ea0b...        7244
#
#                                                   uri subsection_name
# 0   nyt://article/b2f45307-18f3-5671-9316-803b3597...             NaN
# 1   nyt://article/6570bc21-22c3-531a-b313-2eb670a4...        DealBook
# 2   nyt://article/e60c8d0d-c32c-5449-922d-9c664078...        Americas
# 3   nyt://article/3ec05366-9433-55ec-9c2c-d88b4cf0...             NaN
# 4   nyt://article/bb4473f7-e3df-532d-8847-9193187f...          Europe
# 5   nyt://article/dd7a3c99-fc59-57b3-8de4-cac183c3...   Personal Tech
# 6   nyt://article/00281bca-9d5d-5d22-9d2c-7aed99b9...             NaN
# 7   nyt://article/ebd9f6be-d8a6-53c6-9750-e022d7fa...             NaN
# 8   nyt://article/0d4ce260-1a49-590e-9af3-5b507a08...         Economy
# 9   nyt://article/092b7c77-b6b7-58ba-920d-29d39848...        Politics
# 10  nyt://article/6a4fbfe5-0434-56a9-a389-9afc8c34...             NaN
# 11  nyt://article/afd01f3f-4721-5ba1-83ad-8085f4dc...             NaN
# 12  nyt://article/5d87ba91-e910-5fbd-9e70-483282a7...        Politics
# 13  nyt://article/e3da27de-a688-55c0-b7d4-797ac1b7...             NaN
# 14  nyt://article/c7a1d75d-c769-5651-9cb4-d3f66229...        DealBook
# 15  nyt://article/2f7c81b2-5ba9-5b5b-b5b5-112f7a4f...        Politics
# 16  nyt://article/2aeab53d-67d8-5a54-85b0-fd04ea0b...             NaN

# %%
articles_list_df.to_csv('NYT_Cybernews_Jan2022', index=False)

# %% [markdown]
# <details>
#     <summary><strong>Activity 03 Solution ✅</strong></summary>
#
# ```python
#
# # Dependencies
# import requests
# from config import nytapi_key
# import time
#
# url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"
#
# # Store a search term
# query = "coronavirus"
#
# # Search for articles published between a begin and end date
# begin_date = "20200101"
# end_date = "20200130"
#
# query_url = f"{url}api-key={nytapi_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
#
# # Retrieve articles
# articles = requests.get(query_url).json()
# articles_list = articles["response"]["docs"]
#
# for article in articles_list:
#     print(f'A snippet from the article: {article["snippet"]}')
#     print('---------------------------')
#
# # Print the web_url of each stored article
# print("Your Reading List")
# for article in articles_list:
#     print(article["web_url"])
#
# # BONUS: How would we get 30 results?
# # HINT: Look up the page query param
#
# # Empty list for articles
# articles_list = []
#
# # loop through pages 0-2
# for page in range(0, 3):
#     query_url = f"{url}api-key={nytapi_key}&q={query}&begin_date={begin_date}&end_date={end_date}"
#     # create query with page number
#     query_url = f"{query_url}&page={str(page)}"
#     articles = requests.get(query_url).json()
#
#     # Add a one second interval between queries to stay within API query limits
#     time.sleep(1)
#     # loop through the response and append each article to the list
#     for article in articles["response"]["docs"]:
#         articles_list.append(article)
#
# for article in articles_list:
#     print(article['snippet'])
#     print('---------------------------')
#
#
#
# ```
# </details>

# %% [markdown]
# # Instructor Turn -  04 - JSON Traversal Review - 👩‍🏫🧑‍🏫

# %%
# Dependencies
import json
import os

# Load JSON
filepath = os.path.join(".", "Resources", "youtube_response.json")
with open(filepath) as jsonfile:
    video_json = json.load(jsonfile)

# %%
# Isolate "data items" for easy reading
data = video_json["data"]
data_items = data["items"]

# Retrieve the video's title
title = data_items[0]["title"]
print("Title: ", title)

# %%
# Retrieve the video's rating
rating = data_items[0]["rating"]
print("Rating:", rating)

# %%
# Retrieve the link to the video's default thumbnail
default_thumbnail = data_items[0]["thumbnail"]["default"]
print("Thumbnail: ", default_thumbnail)

# %%
# Retrieve the number of views this video has
view_count = data_items[0]["viewCount"]
print(f"View count: {view_count}")

# %% [markdown]
# # Instructor Turn - 05 - Exception Handling - 👩‍🏫🧑‍🏫

# %%
students = {
    # Name  : Age
    "James": 27,
    "Sarah": 19,
    "Jocelyn": 28
}

print(students["Jezebel"])

print("This line will never print.")

# %%
students = {
    # Name  : Age
    "James": 27,
    "Sarah": 19,
    "Jocelyn": 28
}

# Try to access key that doesn't exist
try:
    students["Jezebel"]
except KeyError:
    print("Oops, that key doesn't exist.")

# "Catching" the error lets the rest of our code execute
print("...But the program doesn't die early!")

# %% [markdown]
# # Student Turn - 06 -  API Exceptions - 👩‍🎓👨‍🎓
#
#
# Not every call placed to an API will return a result. In this activity, you will use try/except to handle errors from API calls.
#
# ### Instructions
#
# * Loop through the characters in the list and send a request to the Star Wars API.
#
# * Create a try clause and an except clause. In the try clause, append the height, mass and character that is available in the Star Wars API. If the character is not available in the Star Wars API, use the except clause to print a message and `pass`.
#
# * Create a DataFrame from the results.
#
# * Drop any rows with null values to remove characters not in the Star Wars universe.
#
# ---

# %%
import json
import requests
import pandas as pd

# %%
# List of character
search_characters = ['R2-D2', 'Darth Vader', 'Godzilla', 'Luke Skywalker', 'Frodo', \
              'Boba Fett', 'Iron Man', 'Jon Snow', 'Han Solo']

# Set url for API
url = 'https://swapi.dev/api/people/?search='

# Set empty lists to hold character's height and mass
height = []
mass = []
character_name = []

# Loop through each character and make API request
for character in search_characters:
    # Create search query, make request and store in json
    query = f"{url} {character}"
    response = requests.get(query).json()
    
    # Try to grab the height and mass of characters if they are available in the Star Wars API
    try:
        height.append(response["results"][0]["height"])
        mass.append(response["results"][0]["mass"])
        character_name.append(character)
        print(f"{character} found")
        
    # Handle exceptions for a character that is not available in the Star Wars API
    except (KeyError, IndexError):
        print("Oops did not find that key!")
# Out:
# R2-D2 found
# Darth Vader found
# Oops did not find that key!
# Luke Skywalker found
# Oops did not find that key!
# Boba Fett found
# Oops did not find that key!
# Oops did not find that key!
# Han Solo found

# %%
# Create DataFrame
pd.DataFrame({
    'character': character_name,
    'height': height,
    'mass': mass
})
# Out:
#         character height  mass
# 0           R2-D2     96    32
# 1     Darth Vader    202   136
# 2  Luke Skywalker    172    77
# 3       Boba Fett    183  78.2
# 4        Han Solo    180    80

# %% [markdown]
# <details>
#     <summary><strong>Activity 06 Solution ✅</strong></summary>
#
# ```python
# import json
# import requests
# import pandas as pd
#
# search_characters = ['R2-D2', 'Darth Vader', 'Godzilla', 'Luke Skywalker', 'Frodo', \
#               'Boba Fett', 'Iron Man', 'Jon Snow', 'Han Solo']
#
# # Set url for API
# url = 'https://swapi.dev/api/people/?search='
#
# # Set empty lists to hold characters height and mass
# height = []
# mass = []
# starwars_characters = []
#
# # Loop through each character
# for character in search_characters:
#
#     # Create search query, make request and store in json
#     query = url + character
#     response = requests.get(query)
#     response_json = response.json()
#
#     # Try to grab the height and mass of characters if they are available in the Star Wars API
#     try:
#         height.append(response_json['results'][0]['height'])
#         mass.append(response_json['results'][0]['mass'])
#         starwars_characters.append(character)
#         print(f"{character} found! Appending stats")
#
#     # Handle exceptions for a character that is not available in the Star Wars API
#     except:
#         # Append null values
#         print("Character not found")
#         pass
#
# # Create DataFrame
# character_height = pd.DataFrame({
#     'character': starwars_characters,
#     'height': height,
#     'mass': mass
# })
# character_height
#
#
#
#
# ```
# </details>

# %% [markdown]
# # Instructor Turn - 07 - Open Weather Request  - 👩‍🏫🧑‍🏫

# %%
# Dependencies
import json
import requests
from config import open_weather_api_key

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "London"

# Build query URL
query_url = url + "appid=" + open_weather_api_key + "&q=" + city

# %%
# Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# Get the temperature from the response
print(f"The weather API responded with: {weather_json}.")

# %% [markdown]
# # Student Turn - 08 - Burundi - 👩‍🎓👨‍🎓

# %% [markdown]
# # Weather in Bujumbura
#
# This activity gives students practice with making API calls and handling responses.
#
# ## Instructions
#
# * Save all of your "config" information—i.e., your API key; the base URL; etc.—before moving on.
#
# * Build your query URL. Check the documentation to figure out how to request temperatures in Celsius.
#
# * Make your request, and save the API response.
#
# * Retrieve the current temperature in Bujumbura from the JSON response.
#
# * Print the temperature to the console.
#
# ## Bonus
#
# * Augment your code to report the temperature in both Fahrenheit _and_ Celsius.
#
# ### Note: Don't forget to change the API key in config.py!

# %%
# Dependencies
import requests
from config import open_weather_api_key

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "Bujumbura"
units = "metric"

# %%
# Build query URL and request your results in Celsius
query = f"{url}appid={open_weather_api_key}&q={city}&metric={units}"

# Get weather data
response = requests.get(query).json()
response
# Out:
# {'coord': {'lon': 29.3644, 'lat': -3.3822},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10n'}],
#  'base': 'stations',
#  'main': {'temp': 294.29,
#   'feels_like': 294.81,
#   'temp_min': 294.29,
#   'temp_max': 294.29,
#   'pressure': 1014,
#   'humidity': 90,
#   'sea_level': 1014,
#   'grnd_level': 924},
#  'visibility': 10000,
#  'wind': {'speed': 0.53, 'deg': 56, 'gust': 0.86},
#  'rain': {'1h': 0.7},
#  'clouds': {'all': 100},
#  'dt': 1643857852,
#  'sys': {'country': 'BI', 'sunrise': 1643861329, 'sunset': 1643905429},
#  'timezone': 7200,
#  'id': 425378,
#  'name': 'Bujumbura',
#  'cod': 200}

# %%
# Get temperature from JSON response
temperature = response['main']['temp']
# Out:
# 294.29

# %%
# Report temperature
temperature
# Out:
# 294.29

# %%
# BONUS

# use list of units


# set up list to hold two different temperatures
units = ['metric','imperial']

# loop throught the list of units and append them to temperatures list

    # Build query URL based on current element in units
    

    # Get weather data
    

    # Get temperature from JSON response

# Report temperatures by accessing each element in the list

# %% [markdown]
# <details>
#     <summary><strong>Activity 08 Solution ✅</strong></summary>
#
# ```python
# # Dependencies
# import requests
# from config import open_weather_api_key
#
#
# # Save config information.
# url = "http://api.openweathermap.org/data/2.5/weather?"
# city = "Bujumbura"
# units = "metric"
#
# # Build query URL and request your results in Celsius
# query_url = f"{url}appid={open_weather_api_key}&q={city}&units={units}"
#
# # Get weather data
# weather_response = requests.get(query_url)
# weather_json = weather_response.json()
#
# # Get temperature from JSON response
# temperature = weather_json["main"]["temp"]
#
# # Report temperature
# print(f"The temperature in Bujumbura is {temperature} C.")
#
# # BONUS
#
# # use list of units
# units = ["metric", "imperial"]
#
# # set up list to hold two different temperatures
# temperatures = []
#
# # loop throught the list of units and append them to temperatures list
# for unit in units:
#     # Build query URL based on current element in units
#     query_url = url + "appid=" + open_weather_api_key + "&q=" + city + "&units=" + unit
#
#     # Get weather data
#     weather_response = requests.get(query_url)
#     weather_json = weather_response.json()
#
#     # Get temperature from JSON response
#     temperature = weather_json["main"]["temp"]
#
#     temperatures.append(temperature)
#
# # Report temperatures by accessing each element in the list
# print(
#     f"The temperature in Bujumbura is {temperatures[0]}C or {temperatures[1]}F.")
#
#
#
#
#
#
# ```
# </details>
